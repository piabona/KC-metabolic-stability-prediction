# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import re
import torch
from tqdm.auto import tqdm
import random
import os


import matplotlib.pyplot as plt
import seaborn as sns


DATA_PATH = '/content/drive/MyDrive/데이콘 캐글 컴페티션/2023신약개발/data/'
SEED = 42


def reset_seeds(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True


device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
train = pd.read_csv(f"{DATA_PATH}train.csv")
test = pd.read_csv(f"{DATA_PATH}test.csv")
submission = pd.read_csv(f"{DATA_PATH}sample_submission.csv")

# %%
train.shape, test.shape, submission.shape
# Out:
# ((3498, 11), (483, 9), (483, 3))

# %%
train
# Out:
#               id                                             SMILES     MLM  \
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  26.010
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  29.270
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1   5.586
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   5.710
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  93.270
# ...          ...                                                ...     ...
# 3493  TRAIN_3493     Cn1nc(CNC(=O)Cn2nc(C(F)(F)F)c3c2CCC3)c(Cl)c1Cl   1.556
# 3494  TRAIN_3494  CCn1[nH]cc/c1=N\C(=O)c1nn(-c2ccccc2)c(=O)c2ccc...  35.560
# 3495  TRAIN_3495                       CCOC(=O)CCCc1nc2cc(N)ccc2n1C  56.150
# 3496  TRAIN_3496                     Nc1cc(C(=O)OCCC2CCOC2=O)cnc1Cl   0.030
# 3497  TRAIN_3497                   COc1ccc(-c2nc(Cc3ccccc3)sc2C)cc1   0.450
#
#          HLM  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  \
# 0     50.680  3.259           400.495                5             2
# 1     50.590  2.169           301.407                2             1
# 2     80.892  1.593           297.358                5             0
# 3      2.000  4.771           494.652                6             0
# 4     99.990  2.335           268.310                3             0
# ...      ...    ...               ...              ...           ...
# 3493   3.079  3.409           396.195                3             1
# 3494  47.630  1.912           359.381                4             1
# 3495   1.790  1.941           261.320                3             1
# 3496   2.770  0.989           284.696                5             1
# 3497   2.650  4.321           295.399                2             0
#
#       Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea
# 0                      8  3.259                      117.37
# 1                      2  2.172                       73.47
# 2                      3  1.585                       62.45
# 3                      5  3.475                       92.60
# 4                      1  2.337                       42.43
# ...                  ...    ...                         ...
# 3493                   5  3.409                       64.74
# 3494                   3  1.844                       77.37
# 3495                   6  2.124                       70.14
# 3496                   5  0.989                       91.51
# 3497                   4  4.321                       50.36
#
# [3498 rows x 11 columns]

# %%
train['SMILES']
# Out:
# 0         CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC
# 1                    Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1
# 2                        CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1
# 3       Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...
# 4                     Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2
#                               ...
# 3493       Cn1nc(CNC(=O)Cn2nc(C(F)(F)F)c3c2CCC3)c(Cl)c1Cl
# 3494    CCn1[nH]cc/c1=N\C(=O)c1nn(-c2ccccc2)c(=O)c2ccc...
# 3495                         CCOC(=O)CCCc1nc2cc(N)ccc2n1C
# 3496                       Nc1cc(C(=O)OCCC2CCOC2=O)cnc1Cl
# 3497                     COc1ccc(-c2nc(Cc3ccccc3)sc2C)cc1
# Name: SMILES, Length: 3498, dtype: object

# %%
pd.DataFrame(train['SMILES'].apply(len)).min(), pd.DataFrame(train['SMILES'].apply(len)).max()
# Out:
# (SMILES    18
#  dtype: int64,
#  SMILES    174
#  dtype: int64)

# %%
# train.corr()
# Out:
# <ipython-input-9-0bc27f030cd9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr()
#                                  MLM       HLM     AlogP  Molecular_Weight  \
# MLM                         1.000000  0.706725 -0.330083         -0.081239
# HLM                         0.706725  1.000000 -0.346022         -0.175117
# AlogP                      -0.330083 -0.346022  1.000000          0.389760
# Molecular_Weight           -0.081239 -0.175117  0.389760          1.000000
# Num_H_Acceptors             0.164510  0.092313 -0.284415          0.471814
# Num_H_Donors                0.210836  0.176549 -0.172222          0.116186
# Num_RotatableBonds         -0.092563 -0.132263  0.111844          0.583711
# LogD                       -0.350146 -0.357456  0.957611          0.369462
# Molecular_PolarSurfaceArea  0.184850  0.094323 -0.298194          0.439114
#
#                             Num_H_Acceptors  Num_H_Donors  Num_RotatableBonds  \
# MLM                                0.164510      0.210836           -0.092563
# HLM                                0.092313      0.176549           -0.132263
# AlogP                             -0.284415     -0.172222            0.111844
# Molecular_Weight                   0.471814      0.116186            0.583711
# Num_H_Acceptors                    1.000000      0.208433            0.474012
# Num_H_Donors                       0.208433      1.000000            0.176871
# Num_RotatableBonds                 0.474012      0.176871            1.000000
# LogD                              -0.305506     -0.212082            0.071659
# Molecular_PolarSurfaceArea         0.714315      0.474614            0.371574
#
#                                 LogD  Molecular_PolarSurfaceArea
# MLM                        -0.350146                    0.184850
# HLM                        -0.357456                    0.094323
# AlogP                       0.957611                   -0.298194
# Molecular_Weight            0.369462                    0.439114
# Num_H_Acceptors            -0.305506                    0.714315
# Num_H_Donors               -0.212082                    0.474614
# Num_RotatableBonds          0.071659                    0.371574
# LogD                        1.000000                   -0.294670
# Molecular_PolarSurfaceArea -0.294670                    1.000000

# %%
# df = pd.DataFrame(train['SMILES'].apply(len))
# train = pd.concat([train, df],axis=1)
# train
# Out:
#               id                                             SMILES     MLM  \
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  26.010
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  29.270
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1   5.586
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   5.710
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  93.270
# ...          ...                                                ...     ...
# 3493  TRAIN_3493     Cn1nc(CNC(=O)Cn2nc(C(F)(F)F)c3c2CCC3)c(Cl)c1Cl   1.556
# 3494  TRAIN_3494  CCn1[nH]cc/c1=N\C(=O)c1nn(-c2ccccc2)c(=O)c2ccc...  35.560
# 3495  TRAIN_3495                       CCOC(=O)CCCc1nc2cc(N)ccc2n1C  56.150
# 3496  TRAIN_3496                     Nc1cc(C(=O)OCCC2CCOC2=O)cnc1Cl   0.030
# 3497  TRAIN_3497                   COc1ccc(-c2nc(Cc3ccccc3)sc2C)cc1   0.450
#
#          HLM  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  \
# 0     50.680  3.259           400.495                5             2
# 1     50.590  2.169           301.407                2             1
# 2     80.892  1.593           297.358                5             0
# 3      2.000  4.771           494.652                6             0
# 4     99.990  2.335           268.310                3             0
# ...      ...    ...               ...              ...           ...
# 3493   3.079  3.409           396.195                3             1
# 3494  47.630  1.912           359.381                4             1
# 3495   1.790  1.941           261.320                3             1
# 3496   2.770  0.989           284.696                5             1
# 3497   2.650  4.321           295.399                2             0
#
#       Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea  SMILES
# 0                      8  3.259                      117.37      47
# 1                      2  2.172                       73.47      36
# 2                      3  1.585                       62.45      32
# 3                      5  3.475                       92.60      63
# 4                      1  2.337                       42.43      35
# ...                  ...    ...                         ...     ...
# 3493                   5  3.409                       64.74      46
# 3494                   3  1.844                       77.37      50
# 3495                   6  2.124                       70.14      28
# 3496                   5  0.989                       91.51      30
# 3497                   4  4.321                       50.36      32
#
# [3498 rows x 12 columns]

# %%
# df = pd.DataFrame(test['SMILES'].apply(len))
# test = pd.concat([test, df],axis=1)
# test
# Out:
#            id                                             SMILES  AlogP  \
# 0    TEST_000            CC(C)Nc1ccnc(N2CCN(Cc3cccs3)C(CCO)C2)n1  2.641
# 1    TEST_001     COc1cc(=O)n(-c2ccccc2)cc1C(=O)N1CCC2(CC1)OCCO2  0.585
# 2    TEST_002  Cc1cccc(NC(=N)/N=c2\nc(O)c(Cc3ccccc3)c(C)[nH]2)c1  4.276
# 3    TEST_003         O=C(c1nc2ncccn2n1)N1CCCn2cc(-c3ccccc3)nc21  1.795
# 4    TEST_004       CCN1CCN(C(=O)c2cc3c(=O)n4cc(C)ccc4nc3n2C)CC1  1.219
# ..        ...                                                ...    ...
# 478  TEST_478                  CCc1noc(CC)c1CC(=O)NCC1(CC)CCCCC1  4.207
# 479  TEST_479     CC(=O)N1CCC2(CC1)OC(=O)C(C)=C2C(=O)N1CCN(C)CC1 -0.608
# 480  TEST_480      CC(C)NC(=O)CN1C(=O)c2ccccc2N2C(=O)c3ccccc3C12  1.792
# 481  TEST_481              Cn1cc(Br)c(=O)c(NC(=O)c2ccc(O)cc2F)c1  0.790
# 482  TEST_482                       CC(C)C(CCN1CCN(C)CC1)c1ccco1  2.782
#
#      Molecular_Weight  Num_H_Acceptors  Num_H_Donors  Num_RotatableBonds  \
# 0             361.505                4             2                   7
# 1             370.399                5             0                   3
# 2             347.414                4             4                   5
# 3             345.358                5             0                   2
# 4             353.418                4             0                   2
# ..                ...              ...           ...                 ...
# 478           306.443                2             1                   7
# 479           335.398                5             0                   1
# 480           349.383                3             1                   3
# 481           341.132                3             2                   2
# 482           250.380                2             0                   5
#
#       LogD  Molecular_PolarSurfaceArea  SMILES
# 0    2.635                       92.76      39
# 1    0.585                       68.31      46
# 2    4.290                       92.86      49
# 3    1.795                       81.21      42
# 4    0.169                       61.15      44
# ..     ...                         ...     ...
# 478  4.207                       55.13      33
# 479 -1.736                       70.16      46
# 480  1.792                       69.72      45
# 481  0.423                       69.64      37
# 482  0.606                       19.62      28
#
# [483 rows x 10 columns]

# %%
# train.corr()
# Out:
# <ipython-input-12-0bc27f030cd9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr()
#                                  MLM       HLM     AlogP  Molecular_Weight  \
# MLM                         1.000000  0.706725 -0.330083         -0.081239
# HLM                         0.706725  1.000000 -0.346022         -0.175117
# AlogP                      -0.330083 -0.346022  1.000000          0.389760
# Molecular_Weight           -0.081239 -0.175117  0.389760          1.000000
# Num_H_Acceptors             0.164510  0.092313 -0.284415          0.471814
# Num_H_Donors                0.210836  0.176549 -0.172222          0.116186
# Num_RotatableBonds         -0.092563 -0.132263  0.111844          0.583711
# LogD                       -0.350146 -0.357456  0.957611          0.369462
# Molecular_PolarSurfaceArea  0.184850  0.094323 -0.298194          0.439114
# SMILES                     -0.010193 -0.112194  0.325890          0.867837
#
#                             Num_H_Acceptors  Num_H_Donors  Num_RotatableBonds  \
# MLM                                0.164510      0.210836           -0.092563
# HLM                                0.092313      0.176549           -0.132263
# AlogP                             -0.284415     -0.172222            0.111844
# Molecular_Weight                   0.471814      0.116186            0.583711
# Num_H_Acceptors                    1.000000      0.208433            0.474012
# Num_H_Donors                       0.208433      1.000000            0.176871
# Num_RotatableBonds                 0.474012      0.176871            1.000000
# LogD                              -0.305506     -0.212082            0.071659
# Molecular_PolarSurfaceArea         0.714315      0.474614            0.371574
# SMILES                             0.448337      0.153282            0.451338
#
#                                 LogD  Molecular_PolarSurfaceArea    SMILES
# MLM                        -0.350146                    0.184850 -0.010193
# HLM                        -0.357456                    0.094323 -0.112194
# AlogP                       0.957611                   -0.298194  0.325890
# Molecular_Weight            0.369462                    0.439114  0.867837
# Num_H_Acceptors            -0.305506                    0.714315  0.448337
# Num_H_Donors               -0.212082                    0.474614  0.153282
# Num_RotatableBonds          0.071659                    0.371574  0.451338
# LogD                        1.000000                   -0.294670  0.309650
# Molecular_PolarSurfaceArea -0.294670                    1.000000  0.430259
# SMILES                      0.309650                    0.430259  1.000000

# %%
train
# Out:
#               id                                             SMILES     MLM  \
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  26.010
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  29.270
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1   5.586
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   5.710
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  93.270
# ...          ...                                                ...     ...
# 3493  TRAIN_3493     Cn1nc(CNC(=O)Cn2nc(C(F)(F)F)c3c2CCC3)c(Cl)c1Cl   1.556
# 3494  TRAIN_3494  CCn1[nH]cc/c1=N\C(=O)c1nn(-c2ccccc2)c(=O)c2ccc...  35.560
# 3495  TRAIN_3495                       CCOC(=O)CCCc1nc2cc(N)ccc2n1C  56.150
# 3496  TRAIN_3496                     Nc1cc(C(=O)OCCC2CCOC2=O)cnc1Cl   0.030
# 3497  TRAIN_3497                   COc1ccc(-c2nc(Cc3ccccc3)sc2C)cc1   0.450
#
#          HLM  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  \
# 0     50.680  3.259           400.495                5             2
# 1     50.590  2.169           301.407                2             1
# 2     80.892  1.593           297.358                5             0
# 3      2.000  4.771           494.652                6             0
# 4     99.990  2.335           268.310                3             0
# ...      ...    ...               ...              ...           ...
# 3493   3.079  3.409           396.195                3             1
# 3494  47.630  1.912           359.381                4             1
# 3495   1.790  1.941           261.320                3             1
# 3496   2.770  0.989           284.696                5             1
# 3497   2.650  4.321           295.399                2             0
#
#       Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea  SMILES
# 0                      8  3.259                      117.37      47
# 1                      2  2.172                       73.47      36
# 2                      3  1.585                       62.45      32
# 3                      5  3.475                       92.60      63
# 4                      1  2.337                       42.43      35
# ...                  ...    ...                         ...     ...
# 3493                   5  3.409                       64.74      46
# 3494                   3  1.844                       77.37      50
# 3495                   6  2.124                       70.14      28
# 3496                   5  0.989                       91.51      30
# 3497                   4  4.321                       50.36      32
#
# [3498 rows x 12 columns]

# %%
train.columns
# Out:
# Index(['id', 'SMILES', 'MLM', 'HLM', 'AlogP', 'Molecular_Weight',
#        'Num_H_Acceptors', 'Num_H_Donors', 'Num_RotatableBonds', 'LogD',
#        'Molecular_PolarSurfaceArea', 'SMILES'],
#       dtype='object')

# %%
# train.columns = ['id', 'SMILES', 'MLM', 'HLM', 'AlogP', 'Molecular_Weight',
#        'Num_H_Acceptors', 'Num_H_Donors', 'Num_RotatableBonds', 'LogD',
#        'Molecular_PolarSurfaceArea', 'SMILES_len']

# %% [markdown]
# # ChemBERTa
# - https://huggingface.co/seyonec/ChemBERTa-zinc-base-v1?text=Paris+is+the+%3Cmask%3E+of+France.

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 24.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.17.1-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 71.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.17.1 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.33.2

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.33.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.17.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %%
# import torch
# from transformers import AutoTokenizer, AutoModelForMaskedLM

# # 모델 이름 설정
# model_name = "seyonec/ChemBERTa-zinc-base-v1"
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = AutoModelForMaskedLM.from_pretrained(model_name)

# # 추출할 SMILES 문자열 정의
# smiles_string = "CCO"  # 예시 SMILES 문자열

# # SMILES 문자열을 인코딩하고 모델에 전달
# inputs = tokenizer(smiles_string, return_tensors="pt", padding=True, truncation=True)
# with torch.no_grad():
#     outputs = model(**inputs)

# # 분자 임베딩 추출
# embeddings = outputs.last_hidden_state.mean(dim=1)  # 평균 풀링을 사용하여 임베딩을 추출

# # 추출된 임베딩 확인
# print("Molecule Embeddings Shape:", embeddings.shape)
# print("Molecule Embeddings:", embeddings)

# %%
import torch
from transformers import AutoTokenizer, AutoModelForMaskedLM

# 모델 이름과 토크나이저 이름 설정
model_name = "seyonec/ChemBERTa-zinc-base-v1"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForMaskedLM.from_pretrained(model_name)

# 추출할 SMILES 문자열 정의
smiles_string = "CCO"  # 예시 SMILES 문자열

# SMILES 문자열을 인코딩하고 모델에 전달
inputs = tokenizer(smiles_string, return_tensors="pt", padding=True, truncation=True)
with torch.no_grad():
    outputs = model(**inputs)

# Masked Language Modeling 작업에서 예측값인 "logits"를 추출
logits = outputs.logits

# 특성 추출
features = logits.mean(dim=1)  # 특성 추출 방법은 평균을 사용했습니다. 다른 방법도 가능합니다.

# 추출된 특성 확인
print("Extracted Features Shape:", features.shape)
print("Extracted Features:", features)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/166 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/501 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/9.43k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/3.21k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/179M [00:00<?, ?B/s]
# Some weights of the model checkpoint at seyonec/ChemBERTa-zinc-base-v1 were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Extracted Features Shape: torch.Size([1, 767])
# Extracted Features: tensor([[-1.1679e+00, -1.4977e+00, -2.0888e+00, -1.8878e+00, -3.2611e+00,
#          -1.9664e+00, -2.4960e+00, -1.0562e+00, -3.9395e+00, -1.9483e+00,
#          -3.1591e+00, -2.8859e+00,  5.4996e-01,  6.6431e-01, -1.4691e+00,
#          -2.2078e+00, -1.2367e+00, -5.7110e-01, -3.2908e+00, -3.2101e-01,
#          -2.2854e+00,  3.2204e+00,  5.8153e-02, -9.9245e-01,  5.5396e-01,
#          -4.2534e-02, -1.3327e+00, -2.2100e+00, -2.3747e+00, -2.3461e+00,
#          -1.2137e+00, -1.8763e+00, -1.8194e+00,  7.3734e-01, -2.6740e+00,
#          -1.9882e+00,  3.3700e-01, -1.5732e+00, -2.3090e+00,  5.4768e+00,
#          -2.7789e+00, -1.4473e+00,  2.8847e+00, -1.9212e+00, -5.3010e-01,
#           6.7692e-01, -2.5265e+00, -2.1813e+00, -1.5182e+00, -2.2657e+00,
#           3.0781e+00,  3.0608e+00, -1.2594e-01, -2.1752e+00, -1.6446e+00,
#           1.3499e+00, -2.1438e+00, -2.3219e+00, -3.1273e+00, -2.0850e+00,
#          -2.5570e+00, -2.5757e+00, -2.9587e+00,  1.6048e+00,  5.6061e-01,
#          -7.9797e-01, -2.0326e+00, -3.4405e+00, -1.4080e+00, -1.5511e+00,
#          -1.7831e+00,  2.9023e+00, -2.4051e+00, -3.0220e+00, -2.2749e+00,
#          -2.3386e+00, -1.9628e+00, -2.0322e+00, -2.7007e+00, -3.0453e+00,
#          -1.2938e+00, -1.6545e+00,  6.1917e-01,  1.2368e+00, -2.6152e+00,
#          -2.0756e+00, -2.6437e+00,  1.4133e+00, -2.0403e+00, -3.1658e+00,
#          -2.1812e+00, -2.0998e+00, -1.9864e+00, -2.4184e+00, -2.5758e+00,
#          -1.6513e+00, -1.5676e+00, -3.2194e+00, -1.6809e+00, -2.6877e+00,
#          -1.4123e+00, -1.8220e+00, -1.9108e+00, -2.7121e+00, -1.8191e+00,
#          -1.8682e+00, -1.6328e+00, -1.3586e+00, -3.0855e+00, -1.9578e+00,
#          -2.0217e+00, -2.5460e+00, -1.4013e+00, -1.8069e+00, -9.9972e-01,
#          -1.9433e+00, -2.8154e+00]])

# %%
features_list = []

for smiles in tqdm(train['SMILES'].tolist()):
        # SMILES 문자열을 인코딩하고 모델에 전달
    inputs = tokenizer(smiles, return_tensors="pt", padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)

    # Masked Language Modeling 작업에서 예측값인 "logits"를 추출
    logits = outputs.logits

    # 특성 추출
    features = logits.mean(dim=1)  # 특성 추출 방법은 평균을 사용했습니다. 다른 방법도 가능합니다.
    features_list.append(features)
    # # 추출된 특성 확인
    # print("Extracted Features Shape:", features.shape)
    # print("Extracted Features:", features)
# Out:
#   0%|          | 0/3498 [00:00<?, ?it/s]

# %%
train['Molecule_Embeddings'] = features_list

# %%
torch.cat(features_list).numpy()
# Out:
# array([[-2.6021812, -2.416166 , -2.331112 , ..., -1.4262753, -1.3408945,
#         -2.887336 ],
#        [-2.6957455, -2.3544765, -2.4149096, ..., -1.1744883, -1.2499803,
#         -2.406683 ],
#        [-2.6537948, -2.5313401, -2.3464794, ..., -1.4779081, -1.5680116,
#         -2.1839519],
#        ...,
#        [-2.6111557, -2.130465 , -2.4433079, ..., -1.3749459, -1.3725666,
#         -2.9375608],
#        [-2.7023823, -2.175494 , -2.347566 , ..., -1.508014 , -1.0166966,
#         -2.7035282],
#        [-2.485038 , -2.1909103, -2.259136 , ..., -1.6437249, -1.6194086,
#         -2.6226118]], dtype=float32)

# %%
X = np.concatenate(features_list, axis=0)

# 전치 수행
X_transposed = X.T
df = pd.DataFrame(X)
df #767개의 열. embedding 정보 포함.
# Out:
#            0         1         2         3         4         5         6    \
# 0    -2.602181 -2.416166 -2.331112 -2.174333 -2.822411 -2.385678 -2.322312
# 1    -2.695745 -2.354476 -2.414910 -1.989317 -2.639670 -2.185341 -2.173566
# 2    -2.653795 -2.531340 -2.346479 -1.918797 -2.537491 -2.759861 -1.968515
# 3    -2.669900 -2.521494 -2.461554 -1.999143 -2.775923 -2.366805 -2.332054
# 4    -2.408910 -2.244952 -2.493243 -1.964388 -2.863209 -2.118309 -2.101366
# ...        ...       ...       ...       ...       ...       ...       ...
# 3493 -2.812243 -2.362064 -2.392483 -2.286793 -2.696639 -2.621839 -2.499537
# 3494 -2.511561 -2.340928 -2.470116 -2.358044 -2.794412 -2.667998 -2.299248
# 3495 -2.611156 -2.130465 -2.443308 -2.409866 -3.105262 -2.331446 -2.334735
# 3496 -2.702382 -2.175494 -2.347566 -2.310582 -2.948305 -2.436399 -2.148951
# 3497 -2.485038 -2.190910 -2.259136 -1.987065 -2.683604 -2.629707 -2.249151
#
#            7         8         9    ...       757       758       759  \
# 0     0.561042 -2.073987 -2.227908  ... -1.991607 -2.373958 -1.335646
# 1     0.673285 -2.034645 -2.337377  ... -2.068422 -2.138847 -1.377813
# 4    -2.082072 -1.147488 -1.611428 -1.303321 -1.607484 -2.613079
# ...        ...       ...       ...       ...       ...       ...
# 3493 -1.896272 -1.650752 -1.621845 -1.248276 -1.392809 -2.582400
# 3494 -1.843468 -1.567010 -1.939841 -1.533525 -1.516160 -2.950501
# 3495 -2.069504 -1.236695 -1.755226 -1.374946 -1.372567 -2.937561
# 3496 -1.695927 -1.434264 -1.777464 -1.508014 -1.016697 -2.703528
# 3497 -1.686092 -1.172289 -1.865599 -1.643725 -1.619409 -2.622612
#
# [3498 rows x 778 columns]

# %%
test['SMILES']
# Out:
#                                                 SMILES  SMILES
# 0              CC(C)Nc1ccnc(N2CCN(Cc3cccs3)C(CCO)C2)n1      39
# 1       COc1cc(=O)n(-c2ccccc2)cc1C(=O)N1CCC2(CC1)OCCO2      46
# 2    Cc1cccc(NC(=N)/N=c2\nc(O)c(Cc3ccccc3)c(C)[nH]2)c1      49
# 3           O=C(c1nc2ncccn2n1)N1CCCn2cc(-c3ccccc3)nc21      42
# 4         CCN1CCN(C(=O)c2cc3c(=O)n4cc(C)ccc4nc3n2C)CC1      44
# ..                                                 ...     ...
# 478                  CCc1noc(CC)c1CC(=O)NCC1(CC)CCCCC1      33
# 479     CC(=O)N1CCC2(CC1)OC(=O)C(C)=C2C(=O)N1CCN(C)CC1      46
# 480      CC(C)NC(=O)CN1C(=O)c2ccccc2N2C(=O)c3ccccc3C12      45
# 481              Cn1cc(Br)c(=O)c(NC(=O)c2ccc(O)cc2F)c1      37
# 482                       CC(C)C(CCN1CCN(C)CC1)c1ccco1      28
#
# [483 rows x 2 columns]

# %%
features_list_test = []

for smiles in tqdm(test['SMILES'].tolist()):
        # SMILES 문자열을 인코딩하고 모델에 전달
    inputs = tokenizer(smiles, return_tensors="pt", padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)

    # Masked Language Modeling 작업에서 예측값인 "logits"를 추출
    logits = outputs.logits

    # 특성 추출
    features = logits.mean(dim=1)  # 특성 추출 방법은 평균을 사용했습니다. 다른 방법도 가능합니다.
    features_list_test.append(features)
    # # 추출된 특성 확인
    # print("Extracted Features Shape:", features.shape)
    # print("Extracted Features:", features)
# Out:
#   0%|          | 0/483 [00:00<?, ?it/s]

# %%
features_list_test
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# test['Molecule_Embeddings'] = 0

# test['Molecule_Embeddings'] = features_list_test

# %%
X = np.concatenate(features_list_test, axis=0)

# 전치 수행
X_transposed = X.T
df_test = pd.DataFrame(X)
df_test #767개의 열. embedding 정보 포함.
# Out:
#           0         1         2         3         4         5         6    \
# 0   -2.911492 -2.429448 -2.290789 -1.885554 -2.582995 -2.265126 -2.102386
# 1   -2.679250 -2.312216 -2.471833 -2.179717 -3.076213 -2.453680 -2.148226
# 2   -2.567198 -2.438649 -2.524597 -2.073301 -2.758177 -2.442147 -2.174640
# 3   -2.619594 -2.140731 -2.174192 -2.299927 -2.760957 -2.632819 -2.174229
# 4   -2.762625 -2.538386 -2.125707 -2.099150 -2.849681 -2.586657 -2.268958
# ..        ...       ...       ...       ...       ...       ...       ...
# 478 -2.527565 -2.196282 -2.387540 -1.839070 -3.013028 -2.386143 -2.261006
# 479 -2.719265 -2.329174 -2.680459 -2.191716 -2.959354 -2.092572 -2.101208
# 480 -3.056160 -2.073884 -2.580395 -2.249451 -2.813703 -2.529265 -2.130109
# 481 -2.434457 -2.532714 -2.485792 -2.135011 -2.544180 -2.306498 -2.336752
# 482 -2.279447 -2.519950 -2.343412 -1.589335 -2.547246 -1.857464 -2.137167
#
#           7         8         9    ...       757       758       759  \
# 0    0.739251 -1.881882 -2.519799  ... -2.017083 -2.284410 -1.434447
# 1    0.606782 -1.942386 -2.290443  ... -2.240098 -2.424101 -1.432492
# 2    0.646876 -1.920426 -2.339089  ... -2.096072 -2.407464 -1.481097
# 3    0.484088 -1.974229 -2.217012  ... -2.182104 -2.419306 -1.450977
# 4    0.570860 -2.093197 -2.494037  ... -2.083350 -2.233258 -1.200382
# ..        ...       ...       ...  ...       ...       ...       ...
# 478  0.644945 -2.040053 -2.443506  ... -2.274590 -2.431700 -1.346033
# 479  0.670284 -1.816799 -2.481618  ... -2.545435 -2.571863 -1.436994
# 480  0.735102 -1.896687 -2.346993  ... -2.006593 -2.375355 -1.517317
# 481  0.508938 -2.372232 -2.542052  ... -2.088274 -2.406288 -1.374177
# 482  1.048036 -1.995936 -2.480280  ... -2.644202 -2.573845 -1.258393
#
#           760       761       762       763       764       765       766
# 0   -2.051644 -2.081381 -1.225608 -1.474840 -0.949214 -1.302934 -2.309808
# 1   -2.081653 -1.994273 -1.329621 -1.749228 -1.627684 -1.439588 -2.820971
# 2   -2.192657 -1.846037 -1.310697 -1.921161 -1.096406 -1.345349 -2.932505
# 3   -2.009630 -1.779920 -1.141035 -1.752328 -1.529193 -1.397301 -2.745353
# 4   -2.050077 -2.039183 -1.174748 -1.718197 -1.384192 -1.354418 -2.636139
# ..        ...       ...       ...       ...       ...       ...       ...
# 478 -1.974325 -1.983659 -1.226110 -1.784125 -1.289819 -1.525416 -2.374346
# 479 -2.085016 -2.097533 -1.404426 -1.696949 -1.087436 -1.045423 -2.596229
# 480 -2.064786 -1.763549 -1.347560 -1.772093 -1.291123 -1.099251 -2.687248
# 481 -2.185571 -1.876330 -1.485279 -1.799034 -1.498245 -1.445723 -2.682884
# 482 -2.322994 -2.317841 -1.051814 -1.428226 -1.081376 -1.616788 -1.971870
#
# [483 rows x 767 columns]

# %%
# torch.cat(features_list).numpy()

# %%
test = pd.concat([test,df_test], axis = 1)

# %%
train.shape, test.shape
# Out:
# ((3498, 778), (483, 776))

# %%
train.columns
# Out:
# Index([                'id',             'SMILES',                'MLM',
#                       'HLM',              'AlogP',   'Molecular_Weight',
#           'Num_H_Acceptors',       'Num_H_Donors', 'Num_RotatableBonds',
#                      'LogD',
#        ...
#                         757,                  758,                  759,
#                         760,                  761,                  762,
#                         763,                  764,                  765,
#                         766],
#       dtype='object', length=778)

# %%
test.columns
# Out:
# Index([                        'id',                     'SMILES',
#                             'AlogP',           'Molecular_Weight',
#                   'Num_H_Acceptors',               'Num_H_Donors',
#                'Num_RotatableBonds',                       'LogD',
#        'Molecular_PolarSurfaceArea',                            0,
#        ...
#                                 757,                          758,
#                                 759,                          760,
#                                 761,                          762,
#                                 763,                          764,
#                                 765,                          766],
#       dtype='object', length=776)

# %%
train.to_csv(f'{DATA_PATH}train_molecule_embeddings.csv', index = False)
test.to_csv(f'{DATA_PATH}test_molecule_embeddings.csv', index = False)

# %% [markdown]
# # 전처리

# %% [markdown]
# ### -> 이상치 제거 (총 18개)

# %%
# 1. 극단치만 판단해서 18개 제거
outliers = train[(train['MLM'] > 100.0) | (train['HLM'] > 100.0) | (train['AlogP'] < -3) | (train['Molecular_Weight'] > 800)
     | (train['Num_H_Acceptors'] > 14) | (train['Num_H_Donors'] > 9) | (train['Num_RotatableBonds'] > 20)
     | (train['LogD'] < -4) | (train['Molecular_PolarSurfaceArea'] > 250)]

# %%
outliers.index
# Out:
# Int64Index([ 179,  662,  834,  983, 1092, 1172, 1239, 1584, 2159, 2258, 2367,
#             2410, 2586, 2711, 2948, 3157, 3247, 3403],
#            dtype='int64')

# %%
train = train.drop(index=outliers.index, axis=0)

# %%
duplicates = train[train.duplicated(subset=['SMILES'], keep=False)]

duplicates.sort_values(by='SMILES')
# Out:
#               id                                             SMILES     MLM  \
# 2276  TRAIN_2276                  C(=C/c1nnn(Cc2ccccc2)n1)\c1ccccc1   1.535
# 451   TRAIN_0451                  C(=C/c1nnn(Cc2ccccc2)n1)\c1ccccc1   0.310
# 2891  TRAIN_2891       CC(=O)Nc1ccc(N2N=C(c3ccc(O)cc3)C(C)CC2=O)cc1  55.950
# 543   TRAIN_0543       CC(=O)Nc1ccc(N2N=C(c3ccc(O)cc3)C(C)CC2=O)cc1  68.485
# 837   TRAIN_0837     CC(=O)Nc1nc2ccc(-c3nn(C(C)C)c4nc(N)ncc34)cc2s1  63.522
# 366   TRAIN_0366     CC(=O)Nc1nc2ccc(-c3nn(C(C)C)c4nc(N)ncc34)cc2s1  73.740
# 1085  TRAIN_1085  CC(C)(C)OC(=O)N1CCC(c2n[nH]c3nc(S(C)(=O)=O)ncc...  23.630
# 2848  TRAIN_2848  CC(C)(C)OC(=O)N1CCC(c2n[nH]c3nc(S(C)(=O)=O)ncc...  40.657
# 2096  TRAIN_2096       CC(C)COc1cc(=O)n2c(c1C(=O)N1CCC(C)CC1)CCCCC2   1.880
# 1666  TRAIN_1666       CC(C)COc1cc(=O)n2c(c1C(=O)N1CCC(C)CC1)CCCCC2   5.494
# 1285  TRAIN_1285  CC(C)NC(=O)c1c(Cl)nn(C)c1NC(=O)c1cc(Br)nn1-c1n...  87.987
# 550   TRAIN_0550  CC(C)NC(=O)c1c(Cl)nn(C)c1NC(=O)c1cc(Br)nn1-c1n...  36.230
# 328   TRAIN_0328  CC1CC(=O)N(c2ccc(-c3cccc(C#N)c3)cc2)N=C1c1ccc(...  86.340
# 2651  TRAIN_2651  CC1CC(=O)N(c2ccc(-c3cccc(C#N)c3)cc2)N=C1c1ccc(...   0.000
# 859   TRAIN_0859                      CCCCC/N=c1\n(C)c(=O)nc2sccn12   2.860
# 2362  TRAIN_2362                      CCCCC/N=c1\n(C)c(=O)nc2sccn12   1.819
# 2534  TRAIN_2534  CCOC(=O)CC1(NC(=O)N2Cc3c(sc4c3CCCC4)-n3cccc3C2...   5.884
# 565   TRAIN_0565  CCOC(=O)CC1(NC(=O)N2Cc3c(sc4c3CCCC4)-n3cccc3C2...   1.000
# 250   TRAIN_0250         CCc1nc2cc(Br)c(C(=O)OC)nc2n1CC(=O)c1ccccc1  50.920
# 2245  TRAIN_2245         CCc1nc2cc(Br)c(C(=O)OC)nc2n1CC(=O)c1ccccc1  96.170
# 1793  TRAIN_1793  CN(C)c1ccc(C2c3cccn3-c3sc4c(c3CN2C(=O)NCc2cccc...  82.778
# 1212  TRAIN_1212  CN(C)c1ccc(C2c3cccn3-c3sc4c(c3CN2C(=O)NCc2cccc...   0.370
# 1451  TRAIN_1451                   CN(C1CCNCC1)S(=O)(=O)c1ccc(Cl)s1  47.830
# 10    TRAIN_0010                   CN(C1CCNCC1)S(=O)(=O)c1ccc(Cl)s1  56.900
# 1914  TRAIN_1914  COC(=O)C1(CCCN(C)CCc2ccc(OC)c(OC)c2)CCCc2c1ccc...  12.690
# 3035  TRAIN_3035  COC(=O)C1(CCCN(C)CCc2ccc(OC)c(OC)c2)CCCc2c1ccc...   9.164
# 2756  TRAIN_2756             COCCOc1cc(=O)n2c(c1C(=O)N1CCCC1)CCOCC2  99.000
# 1747  TRAIN_1747             COCCOc1cc(=O)n2c(c1C(=O)N1CCCC1)CCOCC2  65.340
# 2797  TRAIN_2797  COc1cc(CN2CCC(NC(=O)c3cc4cc(Br)c5ccccc5c4o3)CC...   8.350
# 3161  TRAIN_3161  COc1cc(CN2CCC(NC(=O)c3cc4cc(Br)c5ccccc5c4o3)CC...   0.000
# 2256  TRAIN_2256        COc1ccc(C2=NOC(c3ccc(-c4nnn[nH]4)cc3)C2)cc1  55.770
# 2097  TRAIN_2097        COc1ccc(C2=NOC(c3ccc(-c4nnn[nH]4)cc3)C2)cc1  72.473
# 2805  TRAIN_2805                      COc1ccc(C2=NOC(c3ccsc3)C2)cc1   8.144
# 1968  TRAIN_1968                      COc1ccc(C2=NOC(c3ccsc3)C2)cc1   0.160
# 2081  TRAIN_2081        COc1ccc([C@H]2Oc3cc(OC)cc(OC)c3C[C@H]2O)cc1   0.480
# 450   TRAIN_0450        COc1ccc([C@H]2Oc3cc(OC)cc(OC)c3C[C@H]2O)cc1   0.829
# 3445  TRAIN_3445  COc1cccc(-c2cc(-c3nc4c5cnn(-c6ccccc6)c5ncn4n3)...  74.080
# 1031  TRAIN_1031  COc1cccc(-c2cc(-c3nc4c5cnn(-c6ccccc6)c5ncn4n3)...  99.900
# 106   TRAIN_0106  CS(=O)(=O)N1CCN(CCOc2ccc3c(c2)C(c2cc(F)cc(F)c2...   2.904
# 2336  TRAIN_2336  CS(=O)(=O)N1CCN(CCOc2ccc3c(c2)C(c2cc(F)cc(F)c2...   0.210
# 2511  TRAIN_2511   Cc1cc(=O)[nH]c(SCC(=O)C23CC4CC(CC(C4)C2)C3)c1C#N  14.990
# 2780  TRAIN_2780   Cc1cc(=O)[nH]c(SCC(=O)C23CC4CC(CC(C4)C2)C3)c1C#N   8.389
# 2672  TRAIN_2672    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  40.150
# 1833  TRAIN_1833    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  16.776
# 1315  TRAIN_1315  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  58.237
# 898   TRAIN_0898  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  53.850
# 3346  TRAIN_3346  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  80.700
# 2575  TRAIN_2575  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  31.926
# 2850  TRAIN_2850    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  99.900
# 216   TRAIN_0216    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  40.530
# 3265  TRAIN_3265  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c
# 106  -1.930323 -1.501515 -1.883934 -1.322411 -1.556081 -2.748131
# 2336 -1.930323 -1.501515 -1.883934 -1.322411 -1.556081 -2.748131
# 2511 -1.983537 -1.421149 -1.605187 -1.200947 -1.339692 -2.524347
# 2780 -1.983537 -1.421149 -1.605187 -1.200947 -1.339692 -2.524347
# 2672 -1.927710 -1.243472 -1.953197 -1.679651 -1.594018 -2.746540
# 1833 -1.927710 -1.243472 -1.953197 -1.679651 -1.594018 -2.746540
# 1315 -2.043725 -1.143327 -1.601323 -1.432468 -1.342690 -2.837662
# 898  -2.043725 -1.143327 -1.601323 -1.432468 -1.342690 -2.837662
# 3346 -2.063557 -1.320436 -1.718614 -1.335498 -1.451332 -2.911163
# 2575 -2.063557 -1.320436 -1.718614 -1.335498 -1.451332 -2.911163
# 2850 -2.120409 -1.124050 -1.531582 -1.318419 -1.289543 -2.470385
# 216  -2.120409 -1.124050 -1.531582 -1.318419 -1.289543 -2.470385
# 3265 -1.888545 -1.614089 -1.708353 -1.362896 -1.314545 -3.139786
# 2134 -1.888545 -1.614089 -1.708353 -1.362896 -1.314545 -3.139786
#
# [52 rows x 778 columns]

# %%
processed_duplicate = duplicates.groupby('SMILES')['MLM','HLM'].mean().reset_index()
processed_duplicate
# Out:
# <ipython-input-43-c0f91ccc9bed>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   processed_duplicate = duplicates.groupby('SMILES')['MLM','HLM'].mean().reset_index()
#                                                SMILES      MLM      HLM
# 0                   C(=C/c1nnn(Cc2ccccc2)n1)\c1ccccc1   0.9225  28.0615
# 1        CC(=O)Nc1ccc(N2N=C(c3ccc(O)cc3)C(C)CC2=O)cc1  62.2175  77.9110
# 2      CC(=O)Nc1nc2ccc(-c3nn(C(C)C)c4nc(N)ncc34)cc2s1  68.6310  64.6690
# 3   CC(C)(C)OC(=O)N1CCC(c2n[nH]c3nc(S(C)(=O)=O)ncc...  32.1435  85.6850
# 4        CC(C)COc1cc(=O)n2c(c1C(=O)N1CCC(C)CC1)CCCCC2   3.6870  43.3385
# 5   CC(C)NC(=O)c1c(Cl)nn(C)c1NC(=O)c1cc(Br)nn1-c1n...  62.1085  68.1015
# 6   CC1CC(=O)N(c2ccc(-c3cccc(C#N)c3)cc2)N=C1c1ccc(...  43.1700  31.1300
# 7                       CCCCC/N=c1\n(C)c(=O)nc2sccn12   2.3395  36.8145
# 8   CCOC(=O)CC1(NC(=O)N2Cc3c(sc4c3CCCC4)-n3cccc3C2...   3.4420   3.6015
# 9          CCc1nc2cc(Br)c(C(=O)OC)nc2n1CC(=O)c1ccccc1  73.5450   1.1345
# 10  CN(C)c1ccc(C2c3cccn3-c3sc4c(c3CN2C(=O)NCc2cccc...  41.5740  47.1345
# 11                   CN(C1CCNCC1)S(=O)(=O)c1ccc(Cl)s1  52.3650  69.5790
# 12  COC(=O)C1(CCCN(C)CCc2ccc(OC)c(OC)c2)CCCc2c1ccc...  10.9270  15.1105
# 13             COCCOc1cc(=O)n2c(c1C(=O)N1CCCC1)CCOCC2  82.1700  95.6250
# 14  COc1cc(CN2CCC(NC(=O)c3cc4cc(Br)c5ccccc5c4o3)CC...   4.1750  34.8750
# 15        COc1ccc(C2=NOC(c3ccc(-c4nnn[nH]4)cc3)C2)cc1  64.1215  18.6150
# 16                      COc1ccc(C2=NOC(c3ccsc3)C2)cc1   4.1520   5.9740
# 17        COc1ccc([C@H]2Oc3cc(OC)cc(OC)c3C[C@H]2O)cc1   0.6545   4.1300
# 18  COc1cccc(-c2cc(-c3nc4c5cnn(-c6ccccc6)c5ncn4n3)...  86.9900  69.4465
# 19  CS(=O)(=O)N1CCN(CCOc2ccc3c(c2)C(c2cc(F)cc(F)c2...   1.5570   2.6530
# 20   Cc1cc(=O)[nH]c(SCC(=O)C23CC4CC(CC(C4)C2)C3)c1C#N  11.6895  11.1320
# 21    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  28.4630  24.1955
# 22  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  56.0435  66.1260
# 23  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  56.3130  63.7320
# 24    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  70.2150  93.8400
# 25  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...   6.1730  10.8670

# %%
tmp = pd.merge(processed_duplicate,duplicates,how='left',on='SMILES')

# %% [markdown]
# ### -> 중복치 제거 (총 26개)

# %%
tmp = tmp.iloc[0::2]  # 첫 번째 행부터 시작하여 2씩 증가하여 행 선택
tmp.drop(['MLM_y','HLM_y'],axis =1,inplace=True)

# %%
train = train.drop_duplicates(subset=['SMILES'], keep=False) #기존 train에서 중복치들을 우선 모두 제거
train.shape
# Out:
# (3428, 778)

# %%
tmp.rename(columns={'HLM_x': 'HLM', 'MLM_x': 'MLM'}, inplace=True)

# %%
train = pd.concat([train, tmp], axis=0, ignore_index=True)
train.shape
# Out:
# (3454, 778)

# %% [markdown]
# ## 학습 검증 추론

# %%
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import mean_squared_error

def rmse(y_valid, pred):
    mse = mean_squared_error(y_valid, pred)
    return np.sqrt(mse)

# %%
from sklearn.metrics import make_scorer

rmse_score = make_scorer(rmse, greater_is_better=False)

# %%
# 결측치 채우기
train["AlogP"] = np.where(pd.isna(train["AlogP"]), train["LogD"], train["AlogP"])
test["AlogP"] = np.where(pd.isna(test["AlogP"]), test["LogD"], test["AlogP"])

# %%
train_prop = train.iloc[:, 4:]
test_prop = test.iloc[:, 2:]

target_1 = train['MLM']
target_2 = train['HLM']

# %%
train_prop
# Out:
#       AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  \
# 0     3.259           400.495                5             2
# 1     2.169           301.407                2             1
# 2     1.593           297.358                5             0
# 3     4.771           494.652                6             0
# 4     2.335           268.310                3             0
# ...     ...               ...              ...           ...
# 3449  4.609           340.381                4             1
# 3450  4.282           553.480                5             0
# 3451  4.304           459.520                6             1
# 3452 -1.133           385.417                7             0
# 3453  5.630           466.572                4             0
#
#       Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea         0  \
# 0                      8  3.259                      117.37 -2.602181
# 1                      2  2.172                       73.47 -2.695745
# 2                      3  1.585                       62.45 -2.653795
# 3                      5  3.475                       92.60 -2.669900
# 4                      1  2.337                       42.43 -2.408910
# ...                  ...    ...                         ...       ...
# 3449                   2  4.736                       71.75 -2.569803
# 3450                   7  4.009                       65.98 -2.521334
# 3451                   4  4.304                      113.53 -2.646402
# 3452                   4 -1.133                      108.65 -2.824234
# 3453                   8  5.630                       94.90 -2.850530
#
#              1         2  ...       757       758       759       760  \
# 0    -2.416166 -2.331112  ... -1.991607 -2.373958 -1.335646 -1.965763
# 1    -2.354476 -2.414910  ... -2.068422 -2.138847 -1.377813 -2.052618
# 2    -2.531340 -2.346479  ... -1.888332 -2.102875 -1.464725 -1.870678
# 3    -2.521494 -2.461554  ... -2.056242 -2.363769 -1.080201 -2.008929
# 4    -2.244952 -2.493243  ... -2.373341 -2.469370 -1.234159 -2.271900
# ...        ...       ...  ...       ...       ...       ...       ...
# 3449 -2.460406 -2.307648  ... -1.897803 -2.244878 -1.145704 -1.966325
# 3450 -2.366596 -2.532322  ... -1.963544 -2.406016 -1.321722 -2.236139
# 3451 -2.371946 -2.526056  ... -2.308575 -2.393866 -1.374097 -1.956857
# 3452 -2.312467 -2.399506  ... -2.210922 -2.376919 -1.329937 -2.236022
# 3453 -2.327815 -2.543276  ... -2.380779 -2.416767 -1.284687 -2.127739
#
#            761       762       763       764       765       766
# 0    -2.064113 -1.121240 -1.696131 -1.426275 -1.340894 -2.887336
# 1    -2.012119 -1.122919 -1.606128 -1.174488 -1.249980 -2.406683
# 2    -1.862562 -1.089160 -1.834340 -1.477908 -1.568012 -2.183952
# 3    -2.099958 -1.080875 -1.639401 -1.374620 -1.332347 -2.770781
# 4    -2.082072 -1.147488 -1.611428 -1.303321 -1.607484 -2.613079
# ...        ...       ...       ...       ...       ...       ...
# 3449 -1.927710 -1.243472 -1.953197 -1.679651 -1.594018 -2.746540
# 3450 -2.043725 -1.143327 -1.601323 -1.432468 -1.342690 -2.837662
# 3451 -2.063557 -1.320436 -1.718614 -1.335498 -1.451332 -2.911163
# 3452 -2.120409 -1.124050 -1.531582 -1.318419 -1.289543 -2.470385
# 3453 -1.888545 -1.614089 -1.708353 -1.362896 -1.314545 -3.139786
#
# [3454 rows x 774 columns]

# %%
test_prop
# Out:
#      AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  \
# 0    2.641           361.505                4             2
# 1    0.585           370.399                5             0
# 2    4.276           347.414                4             4
# 3    1.795           345.358                5             0
# 4    1.219           353.418                4             0
# ..     ...               ...              ...           ...
# 478  4.207           306.443                2             1
# 479 -0.608           335.398                5             0
# 480  1.792           349.383                3             1
# 481  0.790           341.132                3             2
# 482  2.782           250.380                2             0
#
#      Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea         0  \
# 0                     7  2.635                       92.76 -2.911492
# 1                     3  0.585                       68.31 -2.679250
# 2                     5  4.290                       92.86 -2.567198
# 3                     2  1.795                       81.21 -2.619594
# 4                     2  0.169                       61.15 -2.762625
# ..                  ...    ...                         ...       ...
# 478                   7  4.207                       55.13 -2.527565
# 479                   1 -1.736                       70.16 -2.719265
# 480                   3  1.792                       69.72 -3.056160
# 481                   2  0.423                       69.64 -2.434457
# 482                   5  0.606                       19.62 -2.279447
#
#             1         2  ...       757       758       759       760  \
# 0   -2.429448 -2.290789  ... -2.017083 -2.284410 -1.434447 -2.051644
# 1   -2.312216 -2.471833  ... -2.240098 -2.424101 -1.432492 -2.081653
# 2   -2.438649 -2.524597  ... -2.096072 -2.407464 -1.481097 -2.192657
# 3   -2.140731 -2.174192  ... -2.182104 -2.419306 -1.450977 -2.009630
# 4   -2.538386 -2.125707  ... -2.083350 -2.233258 -1.200382 -2.050077
# ..        ...       ...  ...       ...       ...       ...       ...
# 478 -2.196282 -2.387540  ... -2.274590 -2.431700 -1.346033 -1.974325
# 479 -2.329174 -2.680459  ... -2.545435 -2.571863 -1.436994 -2.085016
# 480 -2.073884 -2.580395  ... -2.006593 -2.375355 -1.517317 -2.064786
# 481 -2.532714 -2.485792  ... -2.088274 -2.406288 -1.374177 -2.185571
# 482 -2.519950 -2.343412  ... -2.644202 -2.573845 -1.258393 -2.322994
#
#           761       762       763       764       765       766
# 0   -2.081381 -1.225608 -1.474840 -0.949214 -1.302934 -2.309808
# 1   -1.994273 -1.329621 -1.749228 -1.627684 -1.439588 -2.820971
# 2   -1.846037 -1.310697 -1.921161 -1.096406 -1.345349 -2.932505
# 3   -1.779920 -1.141035 -1.752328 -1.529193 -1.397301 -2.745353
# 4   -2.039183 -1.174748 -1.718197 -1.384192 -1.354418 -2.636139
# ..        ...       ...       ...       ...       ...       ...
# 478 -1.983659 -1.226110 -1.784125 -1.289819 -1.525416 -2.374346
# 479 -2.097533 -1.404426 -1.696949 -1.087436 -1.045423 -2.596229
# 480 -1.763549 -1.347560 -1.772093 -1.291123 -1.099251 -2.687248
# 481 -1.876330 -1.485279 -1.799034 -1.498245 -1.445723 -2.682884
# 482 -2.317841 -1.051814 -1.428226 -1.081376 -1.616788 -1.971870
#
# [483 rows x 774 columns]

# %%
train_prop = train_prop.astype(float)  # 모든 열을 float64로 변환
test_prop = test_prop.astype(float)  # 모든 열을 float64로 변환

# %%
object_columns_train = train_prop.select_dtypes(include=['object']).columns.tolist()
print(object_columns_train)
# Out:
# []

# %%
object_columns_test = test_prop.select_dtypes(include=['object']).columns.tolist()
print(object_columns_test)
# Out:
# []

# %%
train_prop.columns = train_prop.columns.astype(str)
test_prop.columns = test_prop.columns.astype(str)

# %%
from sklearn.preprocessing import MinMaxScaler

# Min-Max 스케일링을 위한 객체 생성
scaler = MinMaxScaler()

# Train 데이터를 스케일링하고 변환
train_prop = scaler.fit_transform(train_prop)

# Test 데이터를 스케일링하고 변환
test_prop = scaler.transform(test_prop)

# %%
train_prop = pd.DataFrame(train_prop)
train_prop
# Out:
#            0         1         2      3         4         5         6    \
# 0     0.488883  0.408759  0.416667  0.250  0.470588  0.525975  0.546835
# 1     0.394950  0.231359  0.166667  0.125  0.117647  0.439098  0.336496
# 2     0.345312  0.224110  0.416667  0.000  0.176471  0.392184  0.283695
# 3     0.619183  0.577331  0.500000  0.000  0.294118  0.543238  0.428154
# 4     0.409255  0.172104  0.250000  0.000  0.058824  0.452286  0.187773
# ...        ...       ...       ...    ...       ...       ...       ...
# 3449  0.605222  0.301135  0.333333  0.125  0.117647  0.644022  0.328255
# 3450  0.577042  0.682652  0.416667  0.000  0.411765  0.585918  0.300608
# 3451  0.578938  0.514433  0.500000  0.125  0.235294  0.609495  0.528437
# 3452  0.110393  0.381764  0.583333  0.000  0.235294  0.174952  0.505055
# 3453  0.693209  0.527058  0.333333  0.000  0.470588  0.715473  0.439174
#
#            7         8         9    ...       764       765       766  \
# 0     0.413118  0.371946  0.690973  ...  0.699634  0.596252  0.487355
# 1     0.340423  0.428284  0.624756  ...  0.637765  0.804378  0.452152
# 2     0.373017  0.266764  0.678830  ...  0.782814  0.836221  0.379593
# 3     0.360504  0.275756  0.587898  ...  0.647575  0.605272  0.700611
# 4     0.563281  0.528305  0.562858  ...  0.392177  0.511791  0.572080
# ...        ...       ...       ...  ...       ...       ...       ...
# 3449  0.438275  0.331545  0.709515  ...  0.775185  0.710517  0.645927
# 3450  0.475932  0.417216  0.531977  ...  0.722236  0.567873  0.498978
# 3451  0.378761  0.412330  0.536928  ...  0.444341  0.578629  0.455253
# 3452  0.240594  0.466648  0.636929  ...  0.522993  0.593631  0.492120
# 3453  0.220163  0.452632  0.523321  ...  0.386186  0.558356  0.529897
#
#            767       768       769       770       771       772       773
# 0     0.715031  0.310936  0.717066  0.521505  0.553874  0.567793  0.414553
# 1     0.628800  0.348608  0.715490  0.588881  0.727300  0.623673  0.758518
# 2     0.809433  0.456969  0.747174  0.418043  0.518311  0.428196  0.917908
# 3     0.672175  0.284965  0.754950  0.563973  0.589453  0.573046  0.497963
# 4     0.411093  0.297924  0.692431  0.584914  0.638563  0.403935  0.610817
# ...        ...       ...       ...       ...       ...       ...       ...
# 3449  0.714473  0.409766  0.602349  0.329067  0.379354  0.412211  0.515309
# 3450  0.446598  0.325708  0.696337  0.592478  0.549609  0.566689  0.450101
# 3451  0.723873  0.311339  0.530115  0.504675  0.616400  0.499913  0.397503
# 3452  0.446713  0.270147  0.714429  0.644686  0.628164  0.599356  0.712932
# 3453  0.554219  0.438143  0.254514  0.512356  0.597528  0.583988  0.233895
#
# [3454 rows x 774 columns]

# %%
test_prop = pd.DataFrame(test_prop)
test_prop
# Out:
v = KFold(n_splits=5, shuffle=True, random_state=SEED)

scores = []
for tri, val in tqdm(cv.split(train_prop, target_1)):
    # 학습데이터
    x_train = train_prop.iloc[tri]
    y_train_1 = target_1.iloc[tri]
    y_train_2 = target_2.iloc[tri]

    # 검증데이터
    x_valid = train_prop.iloc[val]
    y_valid_1 = target_1.iloc[val]
    y_valid_2 = target_2.iloc[val]

    # MLM
    model = CatBoostRegressor(random_state=SEED, verbose=0)
    model.fit(x_train, y_train_1)
    pred = model.predict(x_valid)
    score_1 = rmse(y_valid_1, pred)

    #HLM
    model = CatBoostRegressor(random_state=SEED, verbose=0)
    model.fit(x_train, y_train_2)
    pred = model.predict(x_valid)
    score_2 = rmse(y_valid_2, pred)

    score = 0.5*score_1 + 0.5*score_2
    scores.append(score)

print(scores)
np.mean(scores)
# Out:
# 0it [00:00, ?it/s]
# [31.802803651884705, 33.19507553318288, 32.177202439615506, 31.123517988050615, 32.27843634294656]
# 32.11540719113606

# %%
model.fit(train_prop, target_1)
cat_pred_1 = model.predict(test_prop)

model.fit(train_prop, target_2)
cat_pred_2 = model.predict(test_prop)

# %%
# import joblib

# # 모델 저장
# joblib.dump(mlm_model, 'mlm_model.pkl')
# joblib.dump(hlm_model, 'hlm_model.pkl')

# %% [markdown]
# #### AdaBoost

# %%
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import KFold

# cv = KFold(n_splits=5, shuffle=True, random_state=SEED)

# scores = []
# for tri, val in tqdm(cv.split(train_prop, target_1)):
#     # 학습데이터
#     x_train = train_prop.iloc[tri]
#     y_train_1 = target_1.iloc[tri]
#     y_train_2 = target_2.iloc[tri]

#     # 검증데이터
#     x_valid = train_prop.iloc[val]
#     y_valid_1 = target_1.iloc[val]
#     y_valid_2 = target_2.iloc[val]

#     # MLM
#     model = AdaBoostRegressor(random_state=SEED)
#     model.fit(x_train, y_train_1)
#     pred = model.predict(x_valid)
#     score_1 = rmse(y_valid_1, pred)

#     #HLM
#     model = AdaBoostRegressor(random_state=SEED)
#     model.fit(x_train, y_train_2)
#     pred = model.predict(x_valid)
#     score_2 = rmse(y_valid_2, pred)

#     score = 0.5*score_1 + 0.5*score_2
#     scores.append(score)

# print(scores)
# np.mean(scores)
# Out:
# 5it [02:54, 34.82s/it]
# [32.36238469218258, 33.36197027802679, 33.24936591196395, 32.46851128996565, 32.980572138938186]
# 32.88456086221543

# %%
# model.fit(train_prop, target_1)
# ada_pred_1 = model.predict(test_prop)

# model.fit(train_prop, target_2)
# ada_pred_2 = model.predict(test_prop)

# %% [markdown]
# #### randomforest

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

cv = KFold(n_splits=5, shuffle=True, random_state=SEED)

scores = []
for tri, val in tqdm(cv.split(train_prop, target_1)):
    # 학습데이터
    x_train = train_prop.iloc[tri]
    y_train_1 = target_1.iloc[tri]
    y_train_2 = target_2.iloc[tri]

    # 검증데이터
    x_valid = train_prop.iloc[val]
    y_valid_1 = target_1.iloc[val]
    y_valid_2 = target_2.iloc[val]

    # MLM
    model = RandomForestRegressor(random_state=SEED)
    model.fit(x_train, y_train_1)
    pred = model.predict(x_valid)
    score_1 = rmse(y_valid_1, pred)

    #HLM
    model = RandomForestRegressor(random_state=SEED)
    model.fit(x_train, y_train_2)
    pred = model.predict(x_valid)
    score_2 = rmse(y_valid_2, pred)

    score = 0.5*score_1 + 0.5*score_2
    scores.append(score)

print(scores)
np.mean(scores)
# Out:
# 0it [00:00, ?it/s]
# [32.12753751800642, 33.69555781025497, 32.54389039122165, 31.629482312819015, 32.4144383440483]
# 32.48218127527007

# %%
model.fit(train_prop, target_1)
rf_pred_1 = model.predict(test_prop)

model.fit(train_prop, target_2)
rf_pred_2 = model.predict(test_prop)

# %% [markdown]
# #### XGBRegressor

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

cv = KFold(n_splits=5, shuffle=True, random_state=SEED)

scores = []
for tri, val in tqdm(cv.split(train_prop, target_1)):
    # 학습데이터
    x_train = train_prop.iloc[tri]
    y_train_1 = target_1.iloc[tri]
    y_train_2 = target_2.iloc[tri]

    # 검증데이터
    x_valid = train_prop.iloc[val]
    y_valid_1 = target_1.iloc[val]
    y_valid_2 = target_2.iloc[val]

    # MLM
    model = XGBRegressor(random_state=SEED)
    model.fit(x_train, y_train_1, eval_set=[(x_valid, y_valid_1)], eval_metric='rmse')
    pred = model.predict(x_valid)
    score_1 = rmse(y_valid_1, pred)

    # HLM
    model = XGBRegressor(random_state=SEED)
    model.fit(x_train, y_train_2, eval_set=[(x_valid, y_valid_2)], eval_metric='rmse')
    pred = model.predict(x_valid)
    score_2 = rmse(y_valid_2, pred)

    score = 0.5*score_1 + 0.5*score_2
    scores.append(score)

print(scores)
np.mean(scores)
# Out:
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:41.31157
# [1]	validation_0-rmse:36.27654
# [2]	validation_0-rmse:33.64459
# [3]	validation_0-rmse:32.55245
# [4]	validation_0-rmse:31.94340
# [5]	validation_0-rmse:31.87027
# [6]	validation_0-rmse:31.84022
# [7]	validation_0-rmse:31.70661
# [8]	validation_0-rmse:31.75064
# [9]	validation_0-rmse:31.87502
# [10]	validation_0-rmse:32.01014
# [11]	validation_0-rmse:31.95646
# [12]	validation_0-rmse:32.17320
# [13]	validation_0-rmse:32.18563
# [14]	validation_0-rmse:32.20507
# [15]	validation_0-rmse:32.25809
# [16]	validation_0-rmse:32.35511
# [17]	validation_0-rmse:32.34016
# [18]	validation_0-rmse:32.39601
# [19]	validation_0-rmse:32.35373
# [20]	validation_0-rmse:32.32135
# [21]	validation_0-rmse:32.34892
# [22]	validation_0-rmse:32.40157
# [23]	validation_0-rmse:32.39396
# [24]	validation_0-rmse:32.42632
# [25]	validation_0-rmse:32.45448
# [26]	validation_0-rmse:32.47249
# [27]	validation_0-rmse:32.42618
# [28]	validation_0-rmse:32.49055
# [29]	validation_0-rmse:32.55503
# [30]	validation_0-rmse:32.56847
# [31]	validation_0-rmse:32.62429
# [32]	validation_0-rmse:32.59271
# [33]	validation_0-rmse:32.68297
# [34]	validation_0-rmse:32.69721
# [35]	validation_0-rmse:32.69256
# [36]	validation_0-rmse:32.66194
# [37]	validation_0-rmse:32.64412
# [38]	validation_0-rmse:32.65148
# [39]	validation_0-rmse:32.63237
# [40]	validation_0-rmse:32.64011
# [41]	validation_0-rmse:32.66870
# [42]	validation_0-rmse:32.68561
# [43]	validation_0-rmse:32.70330
# [44]	validation_0-rmse:32.68568
# [45]	validation_0-rmse:32.68905
# [46]	validation_0-rmse:32.68778
# [47]	validation_0-rmse:32.70474
# [48]	validation_0-rmse:32.70087
# [49]	validation_0-rmse:32.74185
# [50]	validation_0-rmse:32.74615
# [51]	validation_0-rmse:32.78156
# [55]	validation_0-rmse:35.58363
# [56]	validation_0-rmse:35.61531
# [57]	validation_0-rmse:35.62335
# [58]	validation_0-rmse:35.62125
# [59]	validation_0-rmse:35.61057
# [60]	validation_0-rmse:35.60257
# [61]	validation_0-rmse:35.55980
# [62]	validation_0-rmse:35.57876
# [63]	validation_0-rmse:35.58804
# [64]	validation_0-rmse:35.62539
# [65]	validation_0-rmse:35.61963
# [66]	validation_0-rmse:35.61486
# [67]	validation_0-rmse:35.63491
# [68]	validation_0-rmse:35.63197
# [69]	validation_0-rmse:35.62626
# [70]	validation_0-rmse:35.63087
# [71]	validation_0-rmse:35.63382
# [72]	validation_0-rmse:35.63332
# [73]	validation_0-rmse:35.63056
# [74]	validation_0-rmse:35.62585
# [75]	validation_0-rmse:35.62913
# [76]	validation_0-rmse:35.63800
# [77]	validation_0-rmse:35.63301
# [78]	validation_0-rmse:35.63137
# [79]	validation_0-rmse:35.64508
# [80]	validation_0-rmse:35.64455
# [81]	validation_0-rmse:35.63606
# [82]	validation_0-rmse:35.64932
# [83]	validation_0-rmse:35.66245
# [84]	validation_0-rmse:35.67121
# [85]	validation_0-rmse:35.67274
# [86]	validation_0-rmse:35.67008
# [87]	validation_0-rmse:35.66431
# [88]	validation_0-rmse:35.66974
# [89]	validation_0-rmse:35.67777
# [90]	validation_0-rmse:35.68127
# [91]	validation_0-rmse:35.67573
# [92]	validation_0-rmse:35.68068
# [93]	validation_0-rmse:35.68288
# [94]	validation_0-rmse:35.67402
# [95]	validation_0-rmse:35.67321
# [96]	validation_0-rmse:35.67372
# [97]	validation_0-rmse:35.68099
# [98]	validation_0-rmse:35.68496
# [99]	validation_0-rmse:35.68502
# [33.64680062401787, 35.518329620749846, 34.43849802853055, 33.06093767258726, 34.334995387992194]
# 34.19991226677554

# %%
model.fit(train_prop, target_1)
xgb_pred_1 = model.predict(test_prop)

model.fit(train_prop, target_2)
xgb_pred_2 = model.predict(test_prop)

# %% [markdown]
# #### LGBMRegressor

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

cv = KFold(n_splits=5, shuffle=True, random_state=SEED)

scores = []
for tri, val in tqdm(cv.split(train_prop, target_1)):
    # 학습데이터
    x_train = train_prop.iloc[tri]
    y_train_1 = target_1.iloc[tri]
    y_train_2 = target_2.iloc[tri]

    # 검증데이터
    x_valid = train_prop.iloc[val]
    y_valid_1 = target_1.iloc[val]
    y_valid_2 = target_2.iloc[val]

    # MLM
    model = LGBMRegressor(random_state=SEED, objective='regression')
    model.fit(x_train, y_train_1, eval_set=[(x_valid, y_valid_1)], eval_metric="rmse")
    pred = model.predict(x_valid)
    score_1 = rmse(y_valid_1, pred)

    # HLM
    model = LGBMRegressor(random_state=SEED, objective='regression')
    model.fit(x_train, y_train_2, eval_set=[(x_valid, y_valid_2)], eval_metric="rmse")
    pred = model.predict(x_valid)
    score_2 = rmse(y_valid_2, pred)


    score = 0.5*score_1 + 0.5*score_2
    scores.append(score)

print(scores)
np.mean(scores)
# Out:
# 0it [00:00, ?it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029408 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196641
# [LightGBM] [Info] Number of data points in the train set: 2763, number of used features: 774
# [LightGBM] [Info] Start training from score 37.549743
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049428 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196641
# [LightGBM] [Info] Number of data points in the train set: 2763, number of used features: 774
# [LightGBM] [Info] Start training from score 53.023585
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030992 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196642
# [LightGBM] [Info] Number of data points in the train set: 2763, number of used features: 774
# [LightGBM] [Info] Start training from score 37.414670
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031017 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196642
# [LightGBM] [Info] Number of data points in the train set: 2763, number of used features: 774
# [LightGBM] [Info] Start training from score 53.194288
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029222 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196639
# [LightGBM] [Info] Number of data points in the train set: 2763, number of used features: 774
# [LightGBM] [Info] Start training from score 36.907028
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.051750 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196639
# [LightGBM] [Info] Number of data points in the train set: 2763, number of used features: 774
# [LightGBM] [Info] Start training from score 52.950380
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042247 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196641
# [LightGBM] [Info] Number of data points in the train set: 2763, number of used features: 774
# [LightGBM] [Info] Start training from score 37.227328
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030374 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196641
# [LightGBM] [Info] Number of data points in the train set: 2763, number of used features: 774
# [LightGBM] [Info] Start training from score 53.000728
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029825 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196641
# [LightGBM] [Info] Number of data points in the train set: 2764, number of used features: 774
# [LightGBM] [Info] Start training from score 37.282076
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049588 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196641
# [LightGBM] [Info] Number of data points in the train set: 2764, number of used features: 774
# [LightGBM] [Info] Start training from score 52.875017
# [32.50670182715075, 33.856412676299925, 32.57791679443683, 31.584244919276063, 32.40281811720888]
# 32.58561886687449

# %%
model.fit(train_prop, target_1)
lgbm_pred_1 = model.predict(test_prop)

model.fit(train_prop, target_2)
lgbm_pred_2 = model.predict(test_prop)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038089 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196642
# [LightGBM] [Info] Number of data points in the train set: 3454, number of used features: 774
# [LightGBM] [Info] Start training from score 37.276169
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038110 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196642
# [LightGBM] [Info] Number of data points in the train set: 3454, number of used features: 774
# [LightGBM] [Info] Start training from score 53.008790

# %%
# mlm_pred = (cat_pred_1 + ada_pred_1 + rf_pred_1 + xgb_pred_1 + lgbm_pred_1) / 5
# hlm_pred = (cat_pred_2 + ada_pred_2 +rf_pred_2 + xgb_pred_2 + lgbm_pred_2) / 5

# %%
mlm_pred = (cat_pred_1 + rf_pred_1 + lgbm_pred_1) / 3
hlm_pred = (cat_pred_2 + rf_pred_2 + lgbm_pred_2) / 3

# %%
submission['MLM'] = mlm_pred
submission['HLM'] = hlm_pred

# %%
submission
# Out:
#            id        MLM        HLM
# 0    TEST_000  23.685651  47.797643
# 1    TEST_001  56.479102  77.945344
# 2    TEST_002  39.223625  53.439247
# 3    TEST_003  45.507721  73.584156
# 4    TEST_004  66.290823  78.858035
# ..        ...        ...        ...
# 478  TEST_478  17.544773  36.862662
# 479  TEST_479  75.631404  88.271733
# 480  TEST_480  54.898030  72.452000
# 481  TEST_481  63.882227  69.706789
# 482  TEST_482  25.672886  67.148504
#
# [483 rows x 3 columns]

# %%
submission.to_csv("submission_ML18(chemberta).csv", index=False)

# %%
submission
# Out:
#            id        MLM        HLM
# 0    TEST_000  23.685651  47.797643
# 1    TEST_001  56.479102  77.945344
# 2    TEST_002  39.223625  53.439247
# 3    TEST_003  45.507721  73.584156
# 4    TEST_004  66.290823  78.858035
# ..        ...        ...        ...
# 478  TEST_478  17.544773  36.862662
# 479  TEST_479  75.631404  88.271733
# 480  TEST_480  54.898030  72.452000
# 481  TEST_481  63.882227  69.706789
# 482  TEST_482  25.672886  67.148504
#
# [483 rows x 3 columns]

# %%
sub_16 = pd.read_csv('submission_ML16(preprocess).csv')

# %%
sub_16
# Out:
#            id        MLM        HLM
# 0    TEST_000  34.270580  55.729152
# 1    TEST_001  60.907718  63.722749
# 2    TEST_002  30.194104  51.532413
# 3    TEST_003  57.818966  74.373008
# 4    TEST_004  63.833841  80.345176
# ..        ...        ...        ...
# 478  TEST_478   7.256792  19.426390
# 479  TEST_479  78.237783  86.651548
# 480  TEST_480  48.114328  86.437328
# 481  TEST_481  59.538181  60.353697
# 482  TEST_482  40.521415  61.198059
#
# [483 rows x 3 columns]

# %% [markdown]
# # ChemBERTa-77M-MLM (DeepChem)
# - https://huggingface.co/DeepChem/ChemBERTa-77M-MLM
