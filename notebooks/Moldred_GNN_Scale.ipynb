# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import re
import torch
from tqdm.auto import tqdm
import random
import os


import matplotlib.pyplot as plt
import seaborn as sns


DATA_PATH = '/content/drive/MyDrive/데이콘 캐글 컴페티션/2023신약개발/data/'
SEED = 42


def reset_seeds(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True


device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
train = pd.read_csv(f"{DATA_PATH}train.csv")
test = pd.read_csv(f"{DATA_PATH}test.csv")
submission = pd.read_csv(f"{DATA_PATH}sample_submission.csv")

# %%
train = pd.read_csv(f'{DATA_PATH}train_mordred_1835.csv')
test = pd.read_csv(f'{DATA_PATH}test_mordred_1835.csv')
# Out:
# <ipython-input-4-c1893e741271>:1: DtypeWarning: Columns (151,152,153,160,161,162,169,170,171,178,179,180,187,188,189,196,197,198,205,206,207,214,215,216,223,224,225,232,233,234,241,242,243,244,245,246,247,248,249,250,251,252,352,353,354,355,356,357,358,359,360,367,368,369,376,377,378,385,386,387,394,395,396,403,404,405,412,413,414,421,422,423,430,431,432,439,440,441,448,449,450,457,458,459,460,461,462,463,464,465,466,467,473,474,475,481,482,483,489,490,491,497,498,499,505,506,507,513,514,515,521,522,523,529,530,531,537,538,539,545,546,547,553,554,555,556,557,558,559,560,561,562,563,569,570,571,577,578,579,585,586,587,593,594,595,601,602,603,609,610,611,617,618,619,625,626,627,633,634,635,641,642,643,649,650,651,652,653,826,827,1584,1586,1806) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv(f'{DATA_PATH}train_mordred_1835.csv')

# %% [markdown]
# ### -> 이상치 제거 (총 18개)

# %%
# 1. 극단치만 판단해서 18개 제거
outliers = train[(train['MLM'] > 100.0) | (train['HLM'] > 100.0) | (train['AlogP'] < -3) | (train['Molecular_Weight'] > 800)
     | (train['Num_H_Acceptors'] > 14) | (train['Num_H_Donors'] > 9) | (train['Num_RotatableBonds'] > 20)
     | (train['LogD'] < -4) | (train['Molecular_PolarSurfaceArea'] > 250)]

# %%
outliers.index
# Out:
# Int64Index([ 179,  662,  834,  983, 1092, 1172, 1239, 1584, 2159, 2258, 2367,
#             2410, 2586, 2711, 2948, 3157, 3247, 3403],
#            dtype='int64')

# %%
train = train.drop(index=outliers.index, axis=0)

# %%
train.shape # 3498 -> 3480
# Out:
# (3480, 1837)

# %%
duplicates = train[train.duplicated(subset=['SMILES'], keep=False)]

duplicates.sort_values(by='SMILES')
# Out:
#               id                                             SMILES     MLM  \
# 2276  TRAIN_2276                  C(=C/c1nnn(Cc2ccccc2)n1)\c1ccccc1   1.535
# 451   TRAIN_0451                  C(=C/c1nnn(Cc2ccccc2)n1)\c1ccccc1   0.310
# 2891  TRAIN_2891       CC(=O)Nc1ccc(N2N=C(c3ccc(O)cc3)C(C)CC2=O)cc1  55.950
# 543   TRAIN_0543       CC(=O)Nc1ccc(N2N=C(c3ccc(O)cc3)C(C)CC2=O)cc1  68.485
# 837   TRAIN_0837     CC(=O)Nc1nc2ccc(-c3nn(C(C)C)c4nc(N)ncc34)cc2s1  63.522
# 366   TRAIN_0366     CC(=O)Nc1nc2ccc(-c3nn(C(C)C)c4nc(N)ncc34)cc2s1  73.740
# 1085  TRAIN_1085  CC(C)(C)OC(=O)N1CCC(c2n[nH]c3nc(S(C)(=O)=O)ncc...  23.630
# 2848  TRAIN_2848  CC(C)(C)OC(=O)N1CCC(c2n[nH]c3nc(S(C)(=O)=O)ncc...  40.657
# 2096  TRAIN_2096       CC(C)COc1cc(=O)n2c(c1C(=O)N1CCC(C)CC1)CCCCC2   1.880
# 1666  TRAIN_1666       CC(C)COc1cc(=O)n2c(c1C(=O)N1CCC(C)CC1)CCCCC2   5.494
# 1285  TRAIN_1285  CC(C)NC(=O)c1c(Cl)nn(C)c1NC(=O)c1cc(Br)nn1-c1n...  87.987
# 550   TRAIN_0550  CC(C)NC(=O)c1c(Cl)nn(C)c1NC(=O)c1cc(Br)nn1-c1n...  36.230
# 328   TRAIN_0328  CC1CC(=O)N(c2ccc(-c3cccc(C#N)c3)cc2)N=C1c1ccc(...  86.340
# 2651  TRAIN_2651  CC1CC(=O)N(c2ccc(-c3cccc(C#N)c3)cc2)N=C1c1ccc(...   0.000
# 859   TRAIN_0859                      CCCCC/N=c1\n(C)c(=O)nc2sccn12   2.860
# 2362  TRAIN_2362                      CCCCC/N=c1\n(C)c(=O)nc2sccn12   1.819
# 2534  TRAIN_2534  CCOC(=O)CC1(NC(=O)N2Cc3c(sc4c3CCCC4)-n3cccc3C2...   5.884
# 565   TRAIN_0565  CCOC(=O)CC1(NC(=O)N2Cc3c(sc4c3CCCC4)-n3cccc3C2...   1.000
# 250   TRAIN_0250         CCc1nc2cc(Br)c(C(=O)OC)nc2n1CC(=O)c1ccccc1  50.920
# 2245  TRAIN_2245         CCc1nc2cc(Br)c(C(=O)OC)nc2n1CC(=O)c1ccccc1  96.170
# 1793  TRAIN_1793  CN(C)c1ccc(C2c3cccn3-c3sc4c(c3CN2C(=O)NCc2cccc...  82.778
# 1212  TRAIN_1212  CN(C)c1ccc(C2c3cccn3-c3sc4c(c3CN2C(=O)NCc2cccc...   0.370
# 1451  TRAIN_1451                   CN(C1CCNCC1)S(=O)(=O)c1ccc(Cl)s1  47.830
# 10    TRAIN_0010                   CN(C1CCNCC1)S(=O)(=O)c1ccc(Cl)s1  56.900
# 1914  TRAIN_1914  COC(=O)C1(CCCN(C)CCc2ccc(OC)c(OC)c2)CCCc2c1ccc...  12.690
# 3035  TRAIN_3035  COC(=O)C1(CCCN(C)CCc2ccc(OC)c(OC)c2)CCCc2c1ccc...   9.164
# 2756  TRAIN_2756             COCCOc1cc(=O)n2c(c1C(=O)N1CCCC1)CCOCC2  99.000
# 1747  TRAIN_1747             COCCOc1cc(=O)n2c(c1C(=O)N1CCCC1)CCOCC2  65.340
# 2797  TRAIN_2797  COc1cc(CN2CCC(NC(=O)c3cc4cc(Br)c5ccccc5c4o3)CC...   8.350
# 3161  TRAIN_3161  COc1cc(CN2CCC(NC(=O)c3cc4cc(Br)c5ccccc5c4o3)CC...   0.000
# 2256  TRAIN_2256        COc1ccc(C2=NOC(c3ccc(-c4nnn[nH]4)cc3)C2)cc1  55.770
# 2097  TRAIN_2097        COc1ccc(C2=NOC(c3ccc(-c4nnn[nH]4)cc3)C2)cc1  72.473
# 2805  TRAIN_2805                      COc1ccc(C2=NOC(c3ccsc3)C2)cc1   8.144
# 1968  TRAIN_1968                      COc1ccc(C2=NOC(c3ccsc3)C2)cc1   0.160
# 2081  TRAIN_2081        COc1ccc([C@H]2Oc3cc(OC)cc(OC)c3C[C@H]2O)cc1   0.480
# 450   TRAIN_0450        COc1ccc([C@H]2Oc3cc(OC)cc(OC)c3C[C@H]2O)cc1   0.829
# 3445  TRAIN_3445  COc1cccc(-c2cc(-c3nc4c5cnn(-c6ccccc6)c5ncn4n3)...  74.080
# 1031  TRAIN_1031  COc1cccc(-c2cc(-c3nc4c5cnn(-c6ccccc6)c5ncn4n3)...  99.900
# 106   TRAIN_0106  CS(=O)(=O)N1CCN(CCOc2ccc3c(c2)C(c2cc(F)cc(F)c2...   2.904
# 2336  TRAIN_2336  CS(=O)(=O)N1CCN(CCOc2ccc3c(c2)C(c2cc(F)cc(F)c2...   0.210
# 2511  TRAIN_2511   Cc1cc(=O)[nH]c(SCC(=O)C23CC4CC(CC(C4)C2)C3)c1C#N  14.990
# 2780  TRAIN_2780   Cc1cc(=O)[nH]c(SCC(=O)C23CC4CC(CC(C4)C2)C3)c1C#N   8.389
# 2672  TRAIN_2672    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  40.150
# 1833  TRAIN_1833    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  16.776
# 1315  TRAIN_1315  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  58.237
# 898   TRAIN_0898  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  53.850
# 3346  TRAIN_3346  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  80.700
# 2575  TRAIN_2575  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  31.926
# 2850  TRAIN_2850    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  99.900
# 216   TRAIN_0216    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  40.530
# 3265  TRAIN_3265  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...  10.930
# 2134  TRAIN_2134  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...   1.416
#
#          HLM  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  \
# 2276  31.453  3.556           262.309                3             0
# 451   24.670  3.556           262.309                3             0
# 2891  69.950  2.172           337.372                4             2
# 543   85.872  2.172           337.372                4             2
# 837   62.488  2.293           367.428                5             2
# 366   66.850  2.293           367.428                5             2
# 1085  71.470  1.684           381.450                7             1
# 2848  99.900  1.684           381.450                7             1
# 2096  61.280  2.843           360.490                3             0
# 1666  25.397  2.843           360.490                3             0
# 1285  85.103  3.750           501.165                5             2
# 550   51.100  3.750           501.165                5             2
# 328   62.260  4.449           381.427                4             1
# 2651   0.000  4.449           381.427                4             1
# 859   35.860  2.484           252.336                4             0
# 2362  37.769  2.484           252.336                4             0
# 2534   1.663  6.727           537.736                3             1
# 565    5.540  6.727           537.736                3             1
# 250    0.929  3.815           402.242                5             0
# 2245   1.340  3.815           402.242                5             0
# 1793  86.729  6.501           496.666                1             1
# 1212   7.540  6.501           496.666                1             1
# 1451  99.000  0.767           294.821                3             1
# 10    40.158  0.767           294.821                3             1
# 1914  12.250  5.374           485.612                7             0
# 3035  17.971  5.374           485.612                7             0
# 2756  91.350 -0.811           336.383                5             0
# 1747  99.900 -0.811           336.383                5             0
# 2797  69.750  4.934           553.444                5             1
# 3161   0.000  4.934           553.444                5             1
# 2256  15.300  2.235           321.333                6             1
# 2097  21.930  2.235           321.333                6             1
# 2805  11.348  2.868           259.324                3             0
# 1968   0.600  2.868           259.324                3             0
# 2081   0.730  2.940           316.348                5             1
# 450    7.530  2.940           316.348                5             1
# 3445  86.260  3.908           408.415                6             1
# 1031  52.633  3.908           408.415                6             1
# 106    4.686  3.219           525.567                6             0
# 2336   0.620  3.219           525.567                6             0
# 2511  18.130  3.322           342.455                4             1
# 2780   4.134  3.322           342.455                4             1
# 2672  32.610  4.609           340.381                4             1
# 1833  15.781  4.609           340.381                4             1
# 1315  60.612  4.282           553.480                5             0
# 898   71.640  4.282           553.480                5             0
# 3346  90.890  4.304           459.520                6             1
# 2575  36.574  4.304           459.520                6             1
# 2850  99.900 -1.133           385.417                7             0
# 216   87.780 -1.133           385.417                7             0
# 3265  20.330  5.630           466.572                4             0
# 2134   1.404  5.630           466.572                4             0
#
#       Num_RotatableBonds   LogD  ...      SRW10     TSRW10          MW  \
# 2276                   4  3.556  ...   9.530611  66.421505  262.121846
# 451                    4  3.556  ...   9.530611  66.421505  262.121846
# 2891                   3  2.169  ...  10.107040  59.750412  337.142641
# 543                    3  2.169  ...  10.107040  59.750412  337.142641
# 837                    3  2.307  ...  10.293467  77.575687  367.121529
# 366                    3  2.307  ...  10.293467  77.575687  367.121529
# 1085                   4  1.684  ...  10.273222  75.316682  381.147075
# 2848                   4  1.684  ...  10.273222  75.316682  381.147075
# 2096                   4  2.843  ...  10.154519  68.711453  360.241293
# 1666                   4  2.843  ...  10.154519  68.711453  360.241293
# 1285                   5  3.750  ...  10.279970  80.683787  498.992590
# 550                    5  3.750  ...  10.279970  80.683787  498.992590
# 328                    3  4.446  ...  10.313443  64.672912  381.147727
# 2651                   3  4.446  ...  10.313443  64.672912  381.147727
# 859                    4  2.474  ...   9.659312  63.121099  252.104482
# 2362                   4  2.474  ...   9.659312  63.121099  252.104482
# 2534                   6  6.727  ...  10.675330  91.336427  537.211984
# 565                    6  6.727  ...  10.675330  91.336427  537.211984
# 250                    6  3.819  ...  10.150152  74.109537  401.037503
# 2245                   6  3.819  ...  10.150152  74.109537  401.037503
# 1793                   4  6.501  ...  10.608884  89.211497  496.229683
# 1212                   4  6.501  ...  10.608884  89.211497  496.229683
# 1451                   3  0.388  ...   9.769785  63.492153  294.026347
# 10                     3  0.388  ...   9.769785  63.492153  294.026347
# 1914                  13  3.870  ...  10.543629  71.494342  485.277738
# 3035                  13  3.870  ...  10.543629  71.494342  485.277738
# 2756                   5 -0.811  ...  10.035086  71.928075  336.168522
# 1747                   5 -0.811  ...  10.035086  71.928075  336.168522
# 2797                   7  4.934  ...  10.595909  86.895085  552.125984
# 3161                   7  4.934  ...  10.595909  86.895085  552.125984
# 2256                   4  1.806  ...  10.003559  73.928484  321.122575
# 2097                   4  1.806  ...  10.003559  73.928484  321.122575
# 2805                   3  2.868  ...   9.640238  66.286656  259.066700
# 1968                   3  2.868  ...   9.640238  66.286656  259.066700
# 2081                   4  2.940  ...  10.124268  57.532565  316.131074
# 450                    4  2.940  ...  10.124268  57.532565  316.131074
# 3445                   4  3.909  ...  10.489411  84.504440  408.144707
# 1031                   4  3.909  ...  10.489411  84.504440  408.144707
# 106                    7  3.086  ...  10.640245  88.700935  525.153384
# 2336                   7  3.086  ...  10.640245  88.700935  525.153384
# 2511                   4  3.322  ...  10.478836  59.573074  342.140199
# 2780                   4  3.322  ...  10.478836  59.573074  342.140199
# 2672                   2  4.736  ...  10.344674  77.430819  340.143645
# 1833                   2  4.736  ...  10.344674  77.430819  340.143645
# 1315                   7  4.009  ...  10.593756  88.164476  552.169496
# 898                    7  4.009  ...  10.593756  88.164476  552.169496
# 3346                   4  4.304  ...  10.677177  84.226168  459.136511
# 2575                   4  4.304  ...  10.677177  84.226168  459.136511
# 2850                   4 -1.133  ...  10.177818  79.094663  385.175004
# 216                    4 -1.133  ...  10.177818  79.094663  385.175004
# 3265                   8  5.630  ...  10.410937  83.783308  466.102099
# 2134                   8  5.630  ...  10.410937  83.783308  466.102099
#
#             AMW  WPath  WPol  Zagreb1  Zagreb2   mZagreb1  mZagreb2
# 2276   7.709466    969    23    100.0    112.0   4.444444  4.500000
# 451    7.709466    969    23    100.0    112.0   4.444444  4.500000
# 2891   7.662333   1584    39    130.0    151.0   8.750000  5.444444
# 543    7.662333   1584    39    130.0    151.0   8.750000  5.444444
# 837    8.537710   1673    42    144.0    173.0   8.722222  5.500000
# 366    8.537710   1673    42    144.0    173.0   8.722222  5.500000
# 1085   7.778512   1839    40    142.0    165.0  10.402778  5.319444
# 2848   7.778512   1839    40    142.0    165.0  10.402778  5.319444
# 2096   6.211057   1561    45    134.0    157.0   9.000000  5.750000
# 1666   6.211057   1561    45    134.0    157.0   9.000000  5.750000
# 1285  11.088724   2216    46    152.0    180.0  11.583333  6.305556
# 550   11.088724   2216    46    152.0    180.0  11.583333  6.305556
# 328    7.940578   2426    48    154.0    182.0   8.861111  6.388889
# 2651   7.940578   2426    48    154.0    182.0   8.861111  6.388889
# 859    7.639530    538    24     84.0     98.0   5.805556  3.944444
# 2362   7.639530    538    24     84.0     98.0   5.805556  3.944444
# 2534   7.461278   3860    66    206.0    251.0   9.784722  8.083333
# 565    7.461278   3860    66    206.0    251.0   9.784722  8.083333
# 250    9.781403   1475    41    130.0    155.0   8.750000  5.666667
# 2245   9.781403   1475    41    130.0    155.0   8.750000  5.666667
# 1793   7.297495   3743    65    200.0    243.0   9.444444  7.777778
# 1212   7.297495   3743    65    200.0    243.0   9.444444  7.777778
# 1451   9.188323    503    25     88.0    103.0   6.506944  3.694444
# 10     9.188323    503    25     88.0    103.0   6.506944  3.694444
# 1914   6.557807   4168    62    176.0    210.0  12.562500  8.277778
# 3035   6.557807   4168    62    176.0    210.0  12.562500  8.277778
# 2756   7.003511   1252    40    122.0    144.0   7.277778  5.500000
# 1747   7.003511   1252    40    122.0    144.0   7.277778  5.500000
# 2797   8.494246   4743    62    194.0    233.0  10.944444  8.027778
# 3161   8.494246   4743    62    194.0    233.0  10.944444  8.027778
# 2256   8.233912   1536    34    128.0    151.0   5.777778  5.333333
# 2097   8.233912   1536    34    128.0    151.0   5.777778  5.333333
# 2805   8.356990    655    23     94.0    110.0   4.555556  4.055556
# 1968   8.356990    655    23     94.0    110.0   4.555556  4.055556
# 2081   7.351885   1190    39    120.0    143.0   7.638889  5.277778
# 450    7.351885   1190    39    120.0    143.0   7.638889  5.277778
# 3445   8.683930   2905    51    176.0    215.0   6.972222  6.694444
# 1031   8.683930   2905    51    176.0    215.0   6.972222  6.694444
# 106    8.470216   4661    62    202.0    240.0  11.895833  7.861111
# 2336   8.470216   4661    62    202.0    240.0  11.895833  7.861111
# 2511   7.437830   1334    41    136.0    165.0   7.701389  5.097222
# 2780   7.437830   1334    41    136.0    165.0   7.701389  5.097222
# 2672   8.098658   1730    43    148.0    180.0   6.611111  5.500000
# 1833   8.098658   1730    43    148.0    180.0   6.611111  5.500000
# 1315   8.120140   4874    63    204.0    242.0  12.055556  8.222222
# 898    8.120140   4874    63    204.0    242.0  12.055556  8.222222
# 3346   8.502528   2888    61    186.0    227.0  10.895833  6.944444
# 2575   8.502528   2888    61    186.0    227.0  10.895833  6.944444
# 2850   7.552451   2262    42    148.0    175.0   8.000000  6.222222
# 216    7.552451   2262    42    148.0    175.0   8.000000  6.222222
# 3265   8.631520   3644    49    170.0    200.0   9.791667  6.916667
# 2134   8.631520   3644    49    170.0    200.0   9.791667  6.916667
#
# [52 rows x 1837 columns]

# %%
processed_duplicate = duplicates.groupby('SMILES')['MLM','HLM'].mean().reset_index()
# Out:
# <ipython-input-10-a090693ccaae>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   processed_duplicate = duplicates.groupby('SMILES')['MLM','HLM'].mean().reset_index()

# %%
tmp = pd.merge(processed_duplicate,duplicates,how='left',on='SMILES')

# %% [markdown]
# ### -> 중복치 제거 (총 26개)

# %%
tmp = tmp.iloc[0::2]  # 첫 번째 행부터 시작하여 2씩 증가하여 행 선택
tmp.drop(['MLM_y','HLM_y'],axis =1,inplace=True)

# %%
# tmp.columns = ['SMILES', 'MLM', 'HLM','id',  'AlogP', 'Molecular_Weight',
#        'Num_H_Acceptors', 'Num_H_Donors', 'Num_RotatableBonds', 'LogD',
#        'Molecular_PolarSurfaceArea']

# %%
# processed_duplicate = tmp[['id', 'SMILES', 'MLM', 'HLM', 'AlogP', 'Molecular_Weight',
#        'Num_H_Acceptors', 'Num_H_Donors', 'Num_RotatableBonds', 'LogD',
#        'Molecular_PolarSurfaceArea']]

# %%
train = train.drop_duplicates(subset=['SMILES'], keep=False) #기존 train에서 중복치들을 우선 모두 제거
train.shape
# Out:
# (3428, 1837)

# %%
train
# Out:
#               id                                             SMILES     MLM  \
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  26.010
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  29.270
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1   5.586
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   5.710
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  93.270
# ...          ...                                                ...     ...
# 3493  TRAIN_3493     Cn1nc(CNC(=O)Cn2nc(C(F)(F)F)c3c2CCC3)c(Cl)c1Cl   1.556
# 3494  TRAIN_3494  CCn1[nH]cc/c1=N\C(=O)c1nn(-c2ccccc2)c(=O)c2ccc...  35.560
# 3495  TRAIN_3495                       CCOC(=O)CCCc1nc2cc(N)ccc2n1C  56.150
# 3496  TRAIN_3496                     Nc1cc(C(=O)OCCC2CCOC2=O)cnc1Cl   0.030
# 3497  TRAIN_3497                   COc1ccc(-c2nc(Cc3ccccc3)sc2C)cc1   0.450
#
#          HLM  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  \
# 0     50.680  3.259           400.495                5             2
# 1     50.590  2.169           301.407                2             1
# 2     80.892  1.593           297.358                5             0
# 3      2.000  4.771           494.652                6             0
# 4     99.990  2.335           268.310                3             0
# ...      ...    ...               ...              ...           ...
# 3493   3.079  3.409           396.195                3             1
# 3494  47.630  1.912           359.381                4             1
# 3495   1.790  1.941           261.320                3             1
# 3496   2.770  0.989           284.696                5             1
# 3497   2.650  4.321           295.399                2             0
#
#       Num_RotatableBonds   LogD  ...      SRW10     TSRW10          MW  \
# 0                      8  3.259  ...  10.081676  78.761075  400.156912
# 1                      2  2.172  ...   9.907828  69.149596  301.124883
# 2                      3  1.585  ...  10.144510  70.158066  297.170194
# 3                      5  3.475  ...  10.613467  86.199585  494.246395
# 4                      1  2.337  ...   9.978363  53.872357  268.121178
# ...                  ...    ...  ...        ...        ...         ...
# 3493                   5  3.409  ...  10.208580  77.363487  395.052750
# 3494                   3  1.844  ...  10.291162  75.955433  359.138225
# 3495                   6  2.124  ...   9.677277  66.189153  261.147727
# 3496                   5  0.989  ...   9.604475  65.335399  284.056385
# 3497                   4  4.321  ...   9.797405  68.536462  295.103085
#
#             AMW  WPath  WPol  Zagreb1  Zagreb2   mZagreb1  mZagreb2
# 0      7.695325   2380    40    142.0    165.0   9.500000  6.361111
# 1      7.528122    870    35    112.0    132.0   7.138889  4.527778
# 2      7.248054   1028    36    120.0    145.0   5.277778  4.888889
# 3      7.162991   4170    61    192.0    231.0  10.784722  7.500000
# 4      7.447810    762    32    106.0    125.0   6.277778  4.361111
# ...         ...    ...   ...      ...      ...        ...       ...
# 3493  10.129558   1615    38    136.0    162.0  10.062500  5.250000
# 3494   8.162232   1765    45    144.0    173.0   7.750000  6.027778
# 3495   6.872309    795    26     94.0    108.0   6.916667  4.333333
# 3496   8.876762    812    25     94.0    107.0   6.916667  4.250000
# 3497   7.765871   1017    29    108.0    125.0   5.916667  4.722222
#
# [3428 rows x 1837 columns]

# %%
tmp.shape
# Out:
# (26, 1837)

# %%
tmp.rename(columns={'HLM_x': 'HLM', 'MLM_x': 'MLM'}, inplace=True)

# %%
train = pd.concat([train, tmp], axis=0, ignore_index=True)
train.shape
# Out:
# (3454, 1837)

# %%
train
# Out:
#               id                                             SMILES      MLM  \
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  26.0100
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  29.2700
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1   5.5860
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   5.7100
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  93.2700
# ...          ...                                                ...      ...
# 3449  TRAIN_1833    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  28.4630
# 3450  TRAIN_0898  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  56.0435
# 3451  TRAIN_2575  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  56.3130
# 3452  TRAIN_0216    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  70.2150
# 3453  TRAIN_2134  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...   6.1730
#
#           HLM  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  \
# 0     50.6800  3.259           400.495                5             2
# 1     50.5900  2.169           301.407                2             1
# 2     80.8920  1.593           297.358                5             0
# 3      2.0000  4.771           494.652                6             0
# 4     99.9900  2.335           268.310                3             0
# ...       ...    ...               ...              ...           ...
# 3449  24.1955  4.609           340.381                4             1
# 3450  66.1260  4.282           553.480                5             0
# 3451  63.7320  4.304           459.520                6             1
# 3452  93.8400 -1.133           385.417                7             0
# 3453  10.8670  5.630           466.572                4             0
#
#       Num_RotatableBonds   LogD  ...      SRW10     TSRW10          MW  \
# 0                      8  3.259  ...  10.081676  78.761075  400.156912
# 1                      2  2.172  ...   9.907828  69.149596  301.124883
# 2                      3  1.585  ...  10.144510  70.158066  297.170194
# 3                      5  3.475  ...  10.613467  86.199585  494.246395
# 4                      1  2.337  ...   9.978363  53.872357  268.121178
# ...                  ...    ...  ...        ...        ...         ...
# 3449                   2  4.736  ...  10.344674  77.430819  340.143645
# 3450                   7  4.009  ...  10.593756  88.164476  552.169496
# 3451                   4  4.304  ...  10.677177  84.226168  459.136511
# 3452                   4 -1.133  ...  10.177818  79.094663  385.175004
# 3453                   8  5.630  ...  10.410937  83.783308  466.102099
#
#            AMW  WPath  WPol  Zagreb1  Zagreb2   mZagreb1  mZagreb2
# 0     7.695325   2380    40    142.0    165.0   9.500000  6.361111
# 1     7.528122    870    35    112.0    132.0   7.138889  4.527778
# 2     7.248054   1028    36    120.0    145.0   5.277778  4.888889
# 3     7.162991   4170    61    192.0    231.0  10.784722  7.500000
# 4     7.447810    762    32    106.0    125.0   6.277778  4.361111
# ...        ...    ...   ...      ...      ...        ...       ...
# 3449  8.098658   1730    43    148.0    180.0   6.611111  5.500000
# 3450  8.120140   4874    63    204.0    242.0  12.055556  8.222222
# 3451  8.502528   2888    61    186.0    227.0  10.895833  6.944444
# 3452  7.552451   2262    42    148.0    175.0   8.000000  6.222222
# 3453  8.631520   3644    49    170.0    200.0   9.791667  6.916667
#
# [3454 rows x 1837 columns]

# %% [markdown]
# # Mordred Columns확인

# %% [markdown]
# -  Object Columns (총 575개)
# - train, test 하나라도

# %%
train_prop = train.iloc[:, 4:]
test_prop = test.iloc[:, 2:]

target_1 = train['MLM']
target_2 = train['HLM']

# %%
object_columns_train = []

for column in train_prop.columns:
    dtype = train_prop[column].dtype
    # print(f"Column: {column}, Data Type: {dtype}")
    if dtype == object :
        object_columns_train.append(column)

# %%
object_columns_test = []

for column in test_prop.columns:
    dtype = test_prop[column].dtype
    # print(f"Column: {column}, Data Type: {dtype}")
    if dtype == object :
        object_columns_test.append(column)

# %%
object_columns = object_columns_train + object_columns_test

object_columns = set(object_columns)
object_columns = list(object_columns)

len(object_columns_train), len(object_columns_test), len(object_columns)
# Out:
# (575, 403, 575)

# %%
pure_object_cols_train = []

for i in range(len(object_columns)):
    numeric_values = pd.to_numeric(train_prop[object_columns[i]], errors='coerce')
    column_sum = numeric_values.sum()
    # print('column',i,':', column_sum)
    if column_sum == 0.0:
        pure_object_cols_train.append(object_columns[i])

# %%
pure_object_cols_test = []

for i in range(len(object_columns)):
    numeric_values = pd.to_numeric(test_prop[object_columns[i]], errors='coerce')
    column_sum = numeric_values.sum()
    # print('column',i,':', column_sum)
    if column_sum == 0.0:
        pure_object_cols_test.append(object_columns[i])

# %%
pure_object_cols = pure_object_cols_train + pure_object_cols_test

pure_object_cols = set(pure_object_cols)
pure_object_cols = list(pure_object_cols)


len(pure_object_cols_train), len(pure_object_cols_test), len(pure_object_cols)
# Out:
# (313, 317, 319)

# %% [markdown]
# ## PURE OBJECT COLS 버렷을 때 : LGBM 31.426668504334383

# %%
train_prop.drop(columns =pure_object_cols,inplace=True)
test_prop.drop(columns =pure_object_cols, inplace=True)

# %% [markdown]
# # TOTAL OBJECT COLS 버렸을 때 : LGBM 31.566453305994656

# %%
# train_prop.drop(columns =object_columns,inplace=True)
# test_prop.drop(columns =object_columns, inplace=True)

# %% [markdown]
# # PURE OBJECT COLS + 범주화 안했을 때 : 31.3721918205426

# %%
import pandas as pd

# train_prop_object의 모든 열을 처리
for column_name in train_prop.columns:
    train_prop[column_name] = pd.to_numeric(train_prop[column_name], errors='coerce')

# test_prop_object의 모든 열을 처리
for column_name in test_prop.columns:
    test_prop[column_name] = pd.to_numeric(test_prop[column_name], errors='coerce')

# %%
train_prop.isna().sum().sum(), test_prop.isna().sum().sum()
# Out:
# (196434, 27481)

# %%
train_prop.fillna(0, inplace=True)
test_prop.fillna(0, inplace=True)

# %%
train_prop = train_prop.astype(float)
test_prop = test_prop.astype(float)

# %% [markdown]
# - pure object columns(str) -> 삭제 (319개)
#     - object칼럼 중 합계 0 인 칼럼
#     - 행별로 동일해서 의미없는 object column으로 판단함

# %%
# # 열(column_name)의 숫자 데이터만 추출하여 합계 계산
# numeric_values = pd.to_numeric(train_prop[object_columns[0]], errors='coerce')
# column_sum = numeric_values.sum()
# print(i, column_sum)

# %%
train_prop.head(10)
# Out:
#    AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  Num_RotatableBonds  \
# 0  3.259           400.495              5.0           2.0                 8.0
# 1  2.169           301.407              2.0           1.0                 2.0
# 2  1.593           297.358              5.0           0.0                 3.0
# 3  4.771           494.652              6.0           0.0                 5.0
# 4  2.335           268.310              3.0           0.0                 1.0
# 5  1.335           419.422              4.0           1.0                 7.0
# 6  1.954           547.707              7.0           4.0                 9.0
# 7  2.967           293.343              3.0           0.0                 2.0
# 8 -0.946           347.366              7.0           2.0                 3.0
# 9  1.259           357.453              5.0           2.0                 5.0
#
#     LogD  Molecular_PolarSurfaceArea        ABC      ABCGG  nAcid  ...  \
# 0  3.259                      117.37  21.379612  17.449011    0.0  ...
# 1  2.172                       73.47  16.539255  14.049653    0.0  ...
# 2  1.585                       62.45  17.475469  13.660693    2.0  ...
# 3  3.475                       92.60  27.857311  20.034364    0.0  ...
# 4  2.337                       42.43  15.722758  12.817176    0.0  ...
# 5  1.335                       78.95  23.477072  19.253271    0.0  ...
# 6  0.464                      144.42  19.095142  16.597191    2.0  ...
# 7  2.967                       68.18  16.849242  13.229959    0.0  ...
# 8 -0.723                      104.89  14.906262  12.419742    0.0  ...
# 9 -0.373                       90.04  20.413286  16.665260    0.0  ...
#
#        SRW10     TSRW10          MW       AMW   WPath  WPol  Zagreb1  Zagreb2  \
# 0  10.081676  78.761075  400.156912  7.695325  2380.0  40.0    142.0    165.0
# 1   9.907828  69.149596  301.124883  7.528122   870.0  35.0    112.0    132.0
# 2  10.144510  70.158066  297.170194  7.248054  1028.0  36.0    120.0    145.0
# 3  10.613467  86.199585  494.246395  7.162991  4170.0  61.0    192.0    231.0
# 4   9.978363  53.872357  268.121178  7.447810   762.0  32.0    106.0    125.0
# 5  10.481701  85.464816  419.165663  7.908786  2578.0  52.0    162.0    197.0
# 6  10.200736  59.865252  366.088557  8.513687  1442.0  41.0    128.0    149.0
# 7   9.877605  70.704035  293.062283  9.158196   957.0  32.0    114.0    135.0
# 8   9.925396  66.940188  257.152812  6.767179   686.0  30.0    102.0    122.0
# 9  10.137729  76.595367  357.227708  6.740145  1798.0  39.0    138.0    164.0
#
#     mZagreb1  mZagreb2
# 0   9.500000  6.361111
# 1   7.138889  4.527778
# 2   5.277778  4.888889
# 3  10.784722  7.500000
# 4   6.277778  4.361111
# 5  10.333333  6.611111
# 6  10.951389  5.430556
# 7   4.416667  4.583333
# 8   6.027778  4.194444
# 9   6.888889  5.805556
#
# [10 rows x 1514 columns]

# %%
# len(object_columns), len(pure_object_cols)

# 575개 중에 pure object cols 313개는 object(catboost로) / 나머지는 머신러닝으로 -> 앙상블?

# %%
df_corr = pd.concat([train[['HLM']], train_prop],axis=1)

# %%
hlm_corr = df_corr.corr().sort_values(by='HLM')[:300].index.tolist()

# %%
df_corr2 = pd.concat([train[['MLM']], train_prop],axis=1)

# %%
mlm_corr = df_corr2.corr().sort_values(by='MLM')[:300].index.tolist()

# %%
corr_list = list(set(mlm_corr + hlm_corr))
len(corr_list)
# Out:
# 366

# %% [markdown]
# # PURE OBJECT COLUMNS + 100개만 범주화 했을 때 : 31.450351634625314

# %%
import pandas as pd

# 각 열을 0~10 범주로 나누기
num_bins = 10  # 원하는 범주 수

for col in corr_list:
    bin_edges = pd.qcut(train_prop[col], q=num_bins, labels=False, duplicates='drop')
    bin_labels = [str(i) for i in range(num_bins)]
    train_prop[f'{col}_Category'] = pd.Categorical(bin_edges, categories=range(num_bins), ordered=True)
    train_prop[f'{col}_Category'] = train_prop[f'{col}_Category'].cat.rename_categories(bin_labels)

# 결과 출력
print(train_prop)
# Out:
#       AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  \
# 0     3.259           400.495              5.0           2.0
# 1     2.169           301.407              2.0           1.0
# 2     1.593           297.358              5.0           0.0
# 3     4.771           494.652              6.0           0.0
# 4     2.335           268.310              3.0           0.0
# ...     ...               ...              ...           ...
# 3449  4.609           340.381              4.0           1.0
# 3450  4.282           553.480              5.0           0.0
# 3451  4.304           459.520              6.0           1.0
# 3452 -1.133           385.417              7.0           0.0
# 3453  5.630           466.572              4.0           0.0
#
#       Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea        ABC  \
# 0                    8.0  3.259                      117.37  21.379612
# 1                    2.0  2.172                       73.47  16.539255
# 2                    3.0  1.585                       62.45  17.475469
# 3                    5.0  3.475                       92.60  27.857311
# 4                    1.0  2.337                       42.43  15.722758
# ...                  ...    ...                         ...        ...
# 3449                 2.0  4.736                       71.75  21.189342
# 3450                 7.0  4.009                       65.98  30.031303
# 3451                 4.0  4.304                      113.53  26.501865
# 3452                 4.0 -1.133                      108.65  21.936889
# 3453                 8.0  5.630                       94.90  25.137974
#
#           ABCGG  nAcid  ...  SpMax_Dzi_Category  ATS4pe_Category  \
# 0     17.449011    0.0  ...                   8                4
# 1     14.049653    0.0  ...                   1                4
# 2     13.660693    2.0  ...                   2                4
# 3     20.034364    0.0  ...                   9                9
# 4     12.817176    0.0  ...                   1                2
# ...         ...    ...  ...                 ...              ...
# 3449  15.873494    0.0  ...                   5                3
# 3450  22.567906    0.0  ...                   9                9
# 3451  20.702897    0.0  ...                   7                7
# 3452  17.403250    0.0  ...                   8                7
# 3453  19.345263    0.0  ...                   9                7
#
#       GATS5c_Category  LogEE_Dzv_Category  ATS5i_Category  nBondsKS_Category  \
# 0                   5                   7               5                  7
# 1                   1                   1               4                  3
# 2                   2                   3               5                  4
# 3                   6                   9               9                  9
# 4                   1                   1               2                  1
# ...               ...                 ...             ...                ...
# 3449                7                   4               3                  3
# 3450                5                   9               9                  9
# 3451                6                   7               8                  6
# 3452                0                   8               7                  7
# 3453                5                   8               5                  5
#
#       MPC3_Category  SRW02_Category  ATS2are_Category  VE1_Dzpe_Category
# 0                 5               6                 6                  7
# 1                 2               2                 3                  2
# 2                 4               3                 4                  2
# 3                 9               9                 9                  9
# 4                 2               1                 1                  1
# ...             ...             ...               ...                ...
# 3449              7               6                 3                  5
# 3450              9               9                 9                  9
# 3451              9               9                 7                  9
# 3452              6               6                 8                  7
# 3453              8               8                 7                  8
#
# [3454 rows x 1880 columns]

# %%
num_bins = 10  # 원하는 범주 수

for col in corr_list:
    bin_edges = pd.qcut(test_prop[col], q=num_bins, labels=False, duplicates='drop')
    bin_labels = [str(i) for i in range(num_bins)]
    test_prop[f'{col}_Category'] = pd.Categorical(bin_edges, categories=range(num_bins), ordered=True)
    test_prop[f'{col}_Category'] = test_prop[f'{col}_Category'].cat.rename_categories(bin_labels)

# 결과 출력
print(test_prop)
# Out:
#      AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  \
# 0    2.641           361.505              4.0           2.0
# 1    0.585           370.399              5.0           0.0
# 2    4.276           347.414              4.0           4.0
# 3    1.795           345.358              5.0           0.0
# 4    1.219           353.418              4.0           0.0
# ..     ...               ...              ...           ...
# 478  4.207           306.443              2.0           1.0
# 479 -0.608           335.398              5.0           0.0
# 480  1.792           349.383              3.0           1.0
# 481  0.790           341.132              3.0           2.0
# 482  2.782           250.380              2.0           0.0
#
#      Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea        ABC  \
# 0                   7.0  2.635                       92.76  19.229782
# 1                   3.0  0.585                       68.31  21.229782
# 2                   5.0  4.290                       92.86  20.155669
# 3                   2.0  1.795                       81.21  21.079953
# 4                   2.0  0.169                       61.15  20.620135
# ..                  ...    ...                         ...        ...
# 478                 7.0  4.207                       55.13  16.291966
# 479                 1.0 -1.736                       70.16  18.777305
# 480                 3.0  1.792                       69.72  20.648645
# 481                 2.0  0.423                       69.64  15.343821
# 482                 5.0  0.606                       19.62  13.682318
#
#          ABCGG  nAcid  ...  SpMax_Dzi_Category  ATS4pe_Category  \
# 0    15.428567    0.0  ...                   6                7
# 1    16.881776    0.0  ...                   6                6
# 2    15.481463    0.0  ...                   6                4
# 3    16.076404    0.0  ...                   4                3
# 4    16.065299    0.0  ...                   5                7
# ..         ...    ...  ...                 ...              ...
# 478  14.728760    0.0  ...                   5                7
# 479  15.822051    0.0  ...                   5                8
# 480  16.775304    0.0  ...                   4                6
# 481  13.245018    0.0  ...                   1                0
# 482  12.093020    0.0  ...                   1                5
#
#      GATS5c_Category  LogEE_Dzv_Category  ATS5i_Category  nBondsKS_Category  \
# 0                  3                   7               7                  7
# 1                  3                   7               6                  6
# 2                  9                   6               5                  4
# 3                  4                   5               2                  3
# 4                  6                   5               6                  6
# ..               ...                 ...             ...                ...
# 478                6                   4               8                  7
# 479                4                   5               8                  7
# 480                7                   5               5                  4
# 481                5                   1               0                  0
# 482                5                   1               7                  6
#
#      MPC3_Category  SRW02_Category  ATS2are_Category  VE1_Dzpe_Category
# 0                3               5                 7                  5
# 1                7               6                 7                  6
# 2                3               5                 4                  6
# 3                7               6                 4                  6
# 4                7               6                 7                  6
# ..             ...             ...               ...                ...
# 478              1               2                 6                  3
# 479              5               4                 7                  4
# 480              7               6                 5                  6
# 481              1               1                 0                  2
# 482              0               0                 4                  0
#
# [483 rows x 1880 columns]

# %% [markdown]
# # Mol, 일부원소 추가

# %%
# !pip install Chem
# Out:
# Collecting Chem
#   Downloading chem-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from Chem) (1.23.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from Chem) (3.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from Chem) (1.16.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from Chem) (3.8.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from Chem) (1.11.2)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.10/dist-packages (from Chem) (2.1.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->Chem) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->Chem) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->Chem) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->Chem) (4.66.1)
# Installing collected packages: Chem
# Successfully installed Chem-1.2.0

# %%
# !pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2023.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 41.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.3.3

# %%
from rdkit import Chem, DataStructs
from rdkit.Chem import Descriptors
from rdkit.Chem import AllChem
from rdkit import DataStructs
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole     # 화면에 출력하기 위한 옵션
IPythonConsole.ipython_useSVG=True

# %%
train_prop['mol'] = train['SMILES'].apply(lambda x: Chem.MolFromSmiles(x))
train_prop['mol'] = train_prop['mol'].apply(lambda x: Chem.AddHs(x))
train_prop['num_of_atoms'] = train_prop['mol'].apply(lambda x: x.GetNumAtoms())
train_prop['num_of_heavy_atoms'] = train_prop['mol'].apply(lambda x: x.GetNumHeavyAtoms())
train_prop.head()
# Out:
#    AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  Num_RotatableBonds  \
# 0  3.259           400.495              5.0           2.0                 8.0
# 1  2.169           301.407              2.0           1.0                 2.0
# 2  1.593           297.358              5.0           0.0                 3.0
# 3  4.771           494.652              6.0           0.0                 5.0
# 4  2.335           268.310              3.0           0.0                 1.0
#
#     LogD  Molecular_PolarSurfaceArea        ABC      ABCGG  nAcid  ...  \
# 0  3.259                      117.37  21.379612  17.449011    0.0  ...
# 1  2.172                       73.47  16.539255  14.049653    0.0  ...
# 2  1.585                       62.45  17.475469  13.660693    2.0  ...
# 3  3.475                       92.60  27.857311  20.034364    0.0  ...
# 4  2.337                       42.43  15.722758  12.817176    0.0  ...
#
#    LogEE_Dzv_Category  ATS5i_Category  nBondsKS_Category  MPC3_Category  \
# 0                   7               5                  7              5
# 1                   1               4                  3              2
# 2                   3               5                  4              4
# 3                   9               9                  9              9
# 4                   1               2                  1              2
#
#    SRW02_Category  ATS2are_Category  VE1_Dzpe_Category  \
# 0               6                 6                  7
# 1               2                 3                  2
# 2               3                 4                  2
# 3               9                 9                  9
# 4               1                 1                  1
#
#                                                 mol  num_of_atoms  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x7a66c3bbbb50>            52
# 1  <rdkit.Chem.rdchem.Mol object at 0x7a66c3bbbbc0>            40
# 2  <rdkit.Chem.rdchem.Mol object at 0x7a66c3bbbc30>            41
# 3  <rdkit.Chem.rdchem.Mol object at 0x7a66c3bbbca0>            69
# 4  <rdkit.Chem.rdchem.Mol object at 0x7a66c3bbbd10>            36
#
#    num_of_heavy_atoms
# 0                  28
# 1                  21
# 2                  22
# 3                  35
# 4                  20
#
# [5 rows x 1883 columns]

# %%
# 탄소 패턴을 지정한다
c_patt = Chem.MolFromSmiles('C')
# 이 패턴이 들어있는 곳을 찾는다. 패턴의 수를 세면 탄소 원자가 몇개 들어있는지 알 수 있다
print(train_prop['mol'][0].GetSubstructMatches(c_patt))
# Out:
# ((0,), (1,), (3,), (4,), (5,), (6,), (7,), (9,), (11,), (12,), (13,), (14,), (16,), (17,), (19,), (20,), (23,), (24,), (26,), (27,))

# %% [markdown]
# - num_of_{}_atoms 추가

# %%
# 임의의 패턴(원자)를 몇개 포함하고 있는지를 얻는 함수
def number_of_atoms(atom_list, df):
    for i in atom_list:
        df['num_of_{}_atoms'.format(i)] = train_prop['mol'].apply(lambda x: len(x.GetSubstructMatches(Chem.MolFromSmiles(i))))

number_of_atoms(['C', 'O', 'N', 'Cl'], train_prop) # 탄소, 산소, 질소, 염소
train.head()
# Out:
#            id                                             SMILES     MLM  \
# 0  TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  26.010
# 1  TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  29.270
# 2  TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1   5.586
# 3  TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   5.710
# 4  TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  93.270
#
#       HLM  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  \
# 0  50.680  3.259           400.495                5             2
# 1  50.590  2.169           301.407                2             1
# 2  80.892  1.593           297.358                5             0
# 3   2.000  4.771           494.652                6             0
# 4  99.990  2.335           268.310                3             0
#
#    Num_RotatableBonds   LogD  ...      SRW10     TSRW10          MW       AMW  \
# 0                   8  3.259  ...  10.081676  78.761075  400.156912  7.695325
# 1                   2  2.172  ...   9.907828  69.149596  301.124883  7.528122
# 2                   3  1.585  ...  10.144510  70.158066  297.170194  7.248054
# 3                   5  3.475  ...  10.613467  86.199585  494.246395  7.162991
# 4                   1  2.337  ...   9.978363  53.872357  268.121178  7.447810
#
#    WPath  WPol  Zagreb1  Zagreb2   mZagreb1  mZagreb2
# 0   2380    40    142.0    165.0   9.500000  6.361111
# 1    870    35    112.0    132.0   7.138889  4.527778
# 2   1028    36    120.0    145.0   5.277778  4.888889
# 3   4170    61    192.0    231.0  10.784722  7.500000
# 4    762    32    106.0    125.0   6.277778  4.361111
#
# [5 rows x 1837 columns]

# %% [markdown]
# - 테스트 데이터에도 추가

# %%
test_prop['mol'] = test['SMILES'].apply(lambda x: Chem.MolFromSmiles(x))
test_prop['mol'] = test_prop['mol'].apply(lambda x: Chem.AddHs(x))
test_prop['num_of_atoms'] = test_prop['mol'].apply(lambda x: x.GetNumAtoms())
test_prop['num_of_heavy_atoms'] = test_prop['mol'].apply(lambda x: x.GetNumHeavyAtoms())

number_of_atoms(['C','O', 'N', 'Cl'], test_prop)
test.head()
# Out:
#          id                                             SMILES  AlogP  \
# 0  TEST_000            CC(C)Nc1ccnc(N2CCN(Cc3cccs3)C(CCO)C2)n1  2.641
# 1  TEST_001     COc1cc(=O)n(-c2ccccc2)cc1C(=O)N1CCC2(CC1)OCCO2  0.585
# 2  TEST_002  Cc1cccc(NC(=N)/N=c2\nc(O)c(Cc3ccccc3)c(C)[nH]2)c1  4.276
# 3  TEST_003         O=C(c1nc2ncccn2n1)N1CCCn2cc(-c3ccccc3)nc21  1.795
# 4  TEST_004       CCN1CCN(C(=O)c2cc3c(=O)n4cc(C)ccc4nc3n2C)CC1  1.219
#
#    Molecular_Weight  Num_H_Acceptors  Num_H_Donors  Num_RotatableBonds   LogD  \
# 0           361.505                4             2                   7  2.635
# 1           370.399                5             0                   3  0.585
# 2           347.414                4             4                   5  4.290
# 3           345.358                5             0                   2  1.795
# 4           353.418                4             0                   2  0.169
#
#    Molecular_PolarSurfaceArea        ABC  ...      SRW10     TSRW10  \
# 0                       92.76  19.229782  ...   9.935713  72.422574
# 1                       68.31  21.229782  ...  10.330421  76.111616
# 2                       92.86  20.155669  ...  10.008163  60.614034
# 3                       81.21  21.079953  ...  10.288444  77.464779
# 4                       61.15  20.620135  ...  10.380312  75.874629
#
#            MW       AMW  WPath  WPol  Zagreb1  Zagreb2  mZagreb1  mZagreb2
# 0  361.193631  6.946031   1607    34    126.0    144.0  7.527778  5.638889
# 1  370.152872  7.554140   1853    45    146.0    175.0  7.840278  5.972222
# 2  347.174610  7.386694   1905    37    132.0    150.0  8.388889  5.722222
# 3  345.133808  8.417898   1673    42    146.0    177.0  6.000000  5.583333
# 4  353.185175  7.207861   1656    47    144.0    176.0  8.722222  5.638889
#
# [5 rows x 1835 columns]

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# from rdkit import Chem
# import pandas as pd

# # SMILES 문자열 리스트 정의
# smiles_list = train['SMILES']

# num_atoms_list = []
# num_bonds_list = []

# for smiles in smiles_list:
#     # SMILES 문자열 파싱
#     mol = Chem.MolFromSmiles(smiles)

#     if mol is not None:
#         # 원자 및 결합 정보 추출
#         num_atoms = mol.GetNumAtoms()
#         num_bonds = mol.GetNumBonds()

#         # 리스트에 정보 추가
#         num_atoms_list.append(num_atoms)
#         num_bonds_list.append(num_bonds)
#     # else:
#     #     # SMILES 문자열을 파싱할 수 없는 경우
#     #     num_atoms_list.append(None)
#     #     num_bonds_list.append(None)

# # 데이터프레임에 새로운 열로 추가
# # train['num_atoms'] = num_atoms_list
# train['num_bonds'] = num_bonds_list

# %%
# from rdkit import Chem
# import pandas as pd

# # SMILES 문자열 리스트 정의
# smiles_list = test['SMILES']

# num_atoms_list = []
# num_bonds_list = []

# for smiles in smiles_list:
#     # SMILES 문자열 파싱
#     mol = Chem.MolFromSmiles(smiles)

#     if mol is not None:
#         # 원자 및 결합 정보 추출
#         num_atoms = mol.GetNumAtoms()
#         num_bonds = mol.GetNumBonds()

#         # 리스트에 정보 추가
#         num_atoms_list.append(num_atoms)
#         num_bonds_list.append(num_bonds)
#     # else:
#     #     # SMILES 문자열을 파싱할 수 없는 경우
#     #     num_atoms_list.append(None)
#     #     num_bonds_list.append(None)

# # 데이터프레임에 새로운 열로 추가
# # test['num_atoms'] = num_atoms_list
# test['num_bonds'] = num_bonds_list

# %% [markdown]
# # GNN : 31.265770026916055

# %%
# !pip install torch

# %%
# !pip install torch-geometric

# %%
# import torch
# from rdkit import Chem
# from rdkit.Chem import AllChem
# from rdkit.Chem import MolFromSmiles
# from torch_geometric.data import Data

# # SMILES 문자열을 입력으로 받아 RDKit Mol 객체로 변환
# def smiles_to_mol(smiles):
#     mol = MolFromSmiles(smiles)
#     mol = Chem.AddHs(mol)  # 수소 원자 추가
#     mol = Chem.MolToSmiles(mol)  # 정규화된 SMILES로 변환
#     mol = Chem.MolFromSmiles(mol)
#     return mol

# # RDKit Mol 객체를 PyTorch Geometric Data로 변환
# def mol_to_geometric_data(mol):
#     num_atoms = mol.GetNumAtoms()
#     edge_indices = []
#     edge_attr = []

#     for bond in mol.GetBonds():
#         start, end = bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()
#         edge_indices.append((start, end))
#         edge_indices.append((end, start))  # 무방향 그래프이므로 역방향 엣지 추가
#         edge_attr.extend([bond.GetBondTypeAsDouble()] * 2)

#     x = torch.eye(num_atoms)  # 노드 피처는 항등 행렬로 초기화

#     data = Data(x=x, edge_index=torch.tensor(edge_indices).t().contiguous(), edge_attr=torch.tensor(edge_attr))
#     return data

# # SMILES 문자열을 입력으로 받아 그래프 데이터로 변환
# def smiles_to_graph(smiles):
#     mol = smiles_to_mol(smiles)
#     data = mol_to_geometric_data(mol)
#     return data

# %%
# # 예제 SMILES 문자열
# smiles_string = "CCO"  # 여기에 원하는 SMILES 문자열을 넣으세요

# # SMILES를 그래프로 변환
# graph_data = smiles_to_graph(smiles_string)

# # 그래프 데이터 확인
# print(graph_data)

# 그래프 데이터에서 필요한 정보를 추출하여 사용하세요

# %%
# graph_data.x.numpy().sum()

# %%
# graph_data.edge_index.numpy().sum()

# %%
graph_data.edge_attr.numpy().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-208cce016dc4> in <cell line: 1>()
# ----> 1 graph_data.edge_attr.numpy().sum()
#
# NameError: name 'graph_data' is not defined

# %%
# # 예제 SMILES 문자열
# smiles_string = train['SMILES'][0]  # 여기에 원하는 SMILES 문자열을 넣으세요

# # SMILES를 그래프로 변환
# graph_data = smiles_to_graph(smiles_string)

# # 그래프 데이터 확인
# print(graph_data)

# %%
# graph_data.x.numpy().sum()

# %%
# graph_data.edge_index.numpy().sum()

# %%
# graph_data.edge_attr.numpy().sum()

# %%
# data.x : 노드 특징 행렬
# [num_nodes, num_node_features]
# data.edge_index : 그래프의 연결성
# [2, num_edges]
# data.edge_attr : 엣지 특징 행렬
# [num_edges, num_edge_features]

# %%
# # 예제 SMILES 문자열
# smiles_string = train['SMILES'][i]  # 여기에 원하는 SMILES 문자열을 넣으세요

# # SMILES를 그래프로 변환
# graph_data = smiles_to_graph(smiles_string)

# # 그래프 데이터 확인
# # print(graph_data)

# train['graph_x'][i] = graph_data.x
# train['graph_index'][i] = graph_data.edge_index
# train['graph_attr'][i] = graph_data.edge_attr




# # 그래프 데이터에서 필요한 정보를 추출하여 사용하세요

# %%
# df = pd.DataFrame(columns=['SMILES', 'graph_x', 'graph_index', 'graph_attr'])
# df['SMILES'] = train['SMILES']

# %%
# df = pd.DataFrame(columns=['SMILES', 'graph_x', 'graph_index', 'graph_attr'])

# # 예제 SMILES 문자열


# smiles_strings = train['SMILES']  # 여기에 원하는 SMILES 문자열을 넣으세요

# # SMILES를 그래프로 변환하고 데이터프레임에 추가
# for smiles_string in smiles_strings:
#     graph_data = smiles_to_graph(smiles_string)  # 앞서 정의한 함수를 사용하여 SMILES를 그래프로 변환

#     # 데이터프레임에 추가
#     df = df.append({'SMILES': smiles_string,
#                           'graph_x': graph_data.x.numpy().sum(),
#                           'graph_index': graph_data.edge_index.numpy().sum(),
#                           'graph_attr': graph_data.edge_attr.numpy().sum()}, ignore_index=True)

# %%
df

# %%
# df_train = df[['graph_x','graph_index','graph_attr']]
# df_train

# train_prop = pd.concat([train_prop,df_train],axis=1)

# %%
# df = pd.DataFrame(columns=['SMILES', 'graph_x', 'graph_index', 'graph_attr'])

# # 예제 SMILES 문자열


# smiles_strings = test['SMILES']  # 여기에 원하는 SMILES 문자열을 넣으세요

# # SMILES를 그래프로 변환하고 데이터프레임에 추가
# for smiles_string in smiles_strings:
#     graph_data = smiles_to_graph(smiles_string)  # 앞서 정의한 함수를 사용하여 SMILES를 그래프로 변환

#     # 데이터프레임에 추가
#     df = df.append({'SMILES': smiles_string,
#                           'graph_x': graph_data.x.numpy().sum(),
#                           'graph_index': graph_data.edge_index.numpy().sum(),
#                           'graph_attr': graph_data.edge_attr.numpy().sum()}, ignore_index=True)

# %%
# df_test = df[['graph_x','graph_index','graph_attr']]
# df_test

# test_prop = pd.concat([test_prop,df_test],axis=1)

# %%
# test_prop

# %%
train_prop.drop(columns='mol', inplace=True)
test_prop.drop(columns='mol', inplace=True)

# %%
train_prop = train_prop.astype(float)
test_prop = test_prop.astype(float)

# %% [markdown]
# # 모델학습, 검증, 제출

# %% [markdown]
# # BIO DL

# %%
from sklearn.metrics import mean_squared_error

def rmse(y_valid, pred):
    mse = mean_squared_error(y_valid, pred)
    return np.sqrt(mse)

# %% [markdown]
# - smiles모델

# %%
# !pip install transformers

# %%
# model_name = "seyonec/PubChem10M_SMILES_BPE_450k"

# %%
# from transformers import AutoTokenizer
# from transformers import AutoModel

# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = AutoModel.from_pretrained(model_name)
# model

# %%
# train_token = tokenizer(train_smiles.tolist(), padding=True)

# %%
# input_ids = np.array(train_token['input_ids'])
# attention_mask = np.array(train_token['attention_mask'])

# input_ids.shape, attention_mask.shape

# %%
# train_prop = pd.DataFrame(train_prop)

# %%
# test_prop = pd.DataFrame(test_prop)

# %%
# attention_mask

# %% [markdown]
# # 모델 학습 및 예측

# %%
train_prop.iloc[:.:-306]

# %%
train_prop =train_prop.iloc[:, : -307]
test_prop = test_prop.iloc[:, : -307]

# %%
train_prop

# %%
train_cat = train_prop.iloc[:, -306:]
test_cat = test_prop.iloc[:, -306:]

# %% [markdown]
# # STANDARD SCALER : 31.252652342708398 *****

# %%
from sklearn.preprocessing import StandardScaler

# 샘플 데이터 생성 (2차원 배열 형태로 가정)

# StandardScaler 객체 생성
scaler = StandardScaler()

# 데이터를 표준 스케일링 (평균이 0, 표준편차가 1로 변환)
train_prop = scaler.fit_transform(train_prop)
test_prop = scaler.transform(test_prop)

train_prop = pd.DataFrame(train_prop)
test_prop = pd.DataFrame(test_prop)

train_prop

# %% [markdown]
# # MINMAX SCALER 31.388637080253783

# %%
# from sklearn.preprocessing import MinMaxScaler

# # 샘플 데이터 생성 (2차원 배열 형태로 가정)

# # StandardScaler 객체 생성
# scaler = MinMaxScaler()

# # 데이터를 표준 스케일링 (평균이 0, 표준편차가 1로 변환)
# train_prop = scaler.fit_transform(train_prop)
# test_prop = scaler.transform(test_prop)

# train_prop = pd.DataFrame(train_prop)
# test_prop = pd.DataFrame(test_prop)

# train_prop

# %% [markdown]
# - power transformer

# %%
# from sklearn.preprocessing import PowerTransformer


# # StandardScaler 객체 생성
# scaler = PowerTransformer()

# # 데이터를 표준 스케일링 (평균이 0, 표준편차가 1로 변환)
# train_prop = scaler.fit_transform(train_prop)
# test_prop = scaler.transform(test_prop)

# train_prop = pd.DataFrame(train_prop)
# test_prop = pd.DataFrame(test_prop)

# train_prop

# %% [markdown]
# # ROBUST SCALER : 31.44811691605782

# %%
# from sklearn.preprocessing import RobustScaler


# # StandardScaler 객체 생성
# scaler_robust = RobustScaler()

# # 데이터를 표준 스케일링 (평균이 0, 표준편차가 1로 변환)
# train_prop = scaler_robust.fit_transform(train_prop)
# test_prop = scaler_robust.transform(test_prop)

# train_prop = pd.DataFrame(train_prop)
# test_prop = pd.DataFrame(test_prop)

# train_prop

# %% [markdown]
# # MAXABS SCALER :31.377457615856507

# %%
# from sklearn.preprocessing import MaxAbsScaler


# # StandardScaler 객체 생성
# scaler_maxabs = MaxAbsScaler()

# # 데이터를 표준 스케일링 (평균이 0, 표준편차가 1로 변환)
# train_prop = scaler_maxabs.fit_transform(train_prop)
# test_prop = scaler_maxabs.transform(test_prop)

# train_prop = pd.DataFrame(train_prop)
# test_prop = pd.DataFrame(test_prop)

# train_prop

# %% [markdown]
# # QuantileTransformer : 31.388637080253783

# %%
# from sklearn.preprocessing import QuantileTransformer


# # StandardScaler 객체 생성
# scaler = QuantileTransformer()

# # 데이터를 표준 스케일링 (평균이 0, 표준편차가 1로 변환)
# train_prop = scaler_maxabs.fit_transform(train_prop)
# test_prop = scaler_maxabs.transform(test_prop)

# train_prop = pd.DataFrame(train_prop)
# test_prop = pd.DataFrame(test_prop)

# train_prop

# %%
# train_prop = train.iloc[:, 4:]
# test_prop = test.iloc[:, 2:]

# import pandas as pd

# # train_prop_object의 모든 열을 처리
# for column_name in train_prop.columns:
#     train_prop[column_name] = pd.to_numeric(train_prop[column_name], errors='coerce')
# # test_prop_object의 모든 열을 처리
# for column_name in train_prop.columns:
#     train_prop[column_name] = pd.to_numeric(train_prop[column_name], errors='coerce')

# import pandas as pd

# # train_prop_object의 모든 열을 처리
# for column_name in test_prop.columns:
#     test_prop[column_name] = pd.to_numeric(test_prop[column_name], errors='coerce')
# # test_prop_object의 모든 열을 처리
# for column_name in test_prop.columns:
#     test_prop[column_name] = pd.to_numeric(test_prop[column_name], errors='coerce')



# train_prop = train_prop.astype(float)
# test_prop = test_prop.astype(float)

# train_prop.fillna(0, inplace=True)
# test_prop.fillna(0, inplace=True)

# %%
from lightgbm import LGBMRegressor

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

cv = KFold(n_splits=5, shuffle=True, random_state=SEED)

scores = []
for tri, val in tqdm(cv.split(train_prop, target_1)):
    # 학습데이터
    x_train = train_prop.iloc[tri]
    y_train_1 = target_1.iloc[tri]
    y_train_2 = target_2.iloc[tri]

    # 검증데이터
    x_valid = train_prop.iloc[val]
    y_valid_1 = target_1.iloc[val]
    y_valid_2 = target_2.iloc[val]

    # MLM
    model = LGBMRegressor(random_state=SEED, objective='regression')
    model.fit(x_train, y_train_1, eval_set=[(x_valid, y_valid_1)], eval_metric="rmse")
    pred = model.predict(x_valid)
    score_1 = rmse(y_valid_1, pred)

    # HLM
    model = LGBMRegressor(random_state=SEED, objective='regression')
    model.fit(x_train, y_train_2, eval_set=[(x_valid, y_valid_2)], eval_metric="rmse")
    pred = model.predict(x_valid)
    score_2 = rmse(y_valid_2, pred)


    score = 0.5*score_1 + 0.5*score_2
    scores.append(score)

print(scores)
np.mean(scores)

# %%
# model.fit(train_prop, target_1)
# lgbm_pred_1 = model.predict(test_prop)

# model.fit(train_prop, target_2)
# lgbm_pred_2 = model.predict(test_prop)

# %%
model.fit(train_prop, target_1)
lgbm_pred_1 = model.predict(test_prop)

model.fit(train_prop, target_2)
lgbm_pred_2 = model.predict(test_prop)

# %%
submission

# %%
ensemble = pd.read_csv(f"{DATA_PATH}ensemble_test_2.csv")
cat_quant = pd.read_csv(f"{DATA_PATH}submission_ML23(cat_quantile) (2).csv")

# %%
mlm_pred = (lgbm_pred_1)*0.2 + ensemble['MLM']*0.5 + cat_quant['MLM']*0.3
hlm_pred = (lgbm_pred_2)*0.2 + ensemble['HLM']* 0.5 + cat_quant['HLM']*0.3

# %%
submission['MLM'] = mlm_pred
submission['HLM'] = hlm_pred

# %%
submission.to_csv(f'{DATA_PATH}submission_cat_lgbm_0923_.csv', index=False)
