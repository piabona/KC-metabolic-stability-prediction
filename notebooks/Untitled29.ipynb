# %%
ensemble=pd.read_csv('ensemble (1).csv')

# %%
import pandas as pd

# %%
cat_lgbm = pd.read_csv('submission_ML22(cat_ensemble).csv')

# %%
ensemble
# Out:
#            id        MLM        HLM
# 0    TEST_000  24.603051  42.723673
# 1    TEST_001  61.920015  77.622212
# 2    TEST_002  37.720648  49.800555
# 3    TEST_003  43.017860  67.295032
# 4    TEST_004  56.066593  73.718269
# ..        ...        ...        ...
# 478  TEST_478  12.449736  37.194541
# 479  TEST_479  77.253204  84.552160
# 480  TEST_480  45.309335  65.568204
# 481  TEST_481  57.610742  68.744090
# 482  TEST_482  33.918065  66.113412
#
# [483 rows x 3 columns]

# %%
cat_lgbm
# Out:
#            id        MLM        HLM
# 0    TEST_000  21.164590  42.585560
# 1    TEST_001  57.471402  76.592449
# 2    TEST_002  32.090034  49.647152
# 3    TEST_003  43.324336  69.446454
# 4    TEST_004  60.870814  70.728257
# ..        ...        ...        ...
# 478  TEST_478  16.113651  38.994701
# 479  TEST_479  74.351972  83.896510
# 480  TEST_480  47.089622  64.072179
# 481  TEST_481  62.522011  74.102734
# 482  TEST_482  26.320007  69.434552
#
# [483 rows x 3 columns]

# %%
mlm = ensemble['MLM']*0.5 + cat_lgbm['MLM']*0.5
hlm = ensemble['HLM']*0.5 + cat_lgbm['HLM']*0.5

# %%
submission = pd.read_csv('sample_submission.csv')

# %%
submission['MLM'] = mlm
submission['HLM'] = hlm

# %%
submission.to_csv('ensemble2_cat_lgbm.csv', index=False)

# %%
ensemble
# Out:
#            id        MLM        HLM
# 0    TEST_000  24.603051  42.723673
# 1    TEST_001  61.920015  77.622212
# 2    TEST_002  37.720648  49.800555
# 3    TEST_003  43.017860  67.295032
# 4    TEST_004  56.066593  73.718269
# ..        ...        ...        ...
# 478  TEST_478  12.449736  37.194541
# 479  TEST_479  77.253204  84.552160
# 480  TEST_480  45.309335  65.568204
# 481  TEST_481  57.610742  68.744090
# 482  TEST_482  33.918065  66.113412
#
# [483 rows x 3 columns]
